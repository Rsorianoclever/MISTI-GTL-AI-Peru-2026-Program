# %% [markdown]
# <a href="https://colab.research.google.com/github/Rsorianoclever/MISTI-GTL-AI-Peru-2026-Program/blob/main/RS_2026MISTIPeru_IntrotoModelTraining_ConvolutionalNeuralNetworks_EXERCISES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If you haven't already, please hit :**
#
# `File` -> `Save a Copy in Drive`
#
# **to copy this notebook to your Google drive, and work on a copy. If you don't do this, your changes won't be saved!**

# %% [markdown]
# # Model Training with Convolutional Neural Networks using MNIST

# %%
# @title
# ==============================================
# 0. Module imports
# ==============================================

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import datasets, transforms

# data manipulation
import pandas as pd
import numpy as np
import scipy.stats as st
import scipy

# plots
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pylab as pl

# classification algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler

# dimension reduction
from sklearn.decomposition import PCA

# cross-validation
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import model_selection

# parallel processing
from joblib import Parallel, delayed
import multiprocessing

# model evaluation
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings("ignore")

import seaborn as sns

device = "cpu"

# %% [markdown]
# Some visualization code. No need to understand this cell, but don't forget to run it!

# %%
# @title
from graphviz import Digraph

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#93D30C", "#8F00FF"]
def visualize(model):
    hidden_layers = []
    output_layer = 0
    layers = [layer for layer in model.modules() if type(layer) == torch.nn.Linear]

    # custom script to get all the shapes of a network's layers
    sizes = list()
    state_dict = net.state_dict()
    for idx, key in enumerate(state_dict.keys()):
      if key.endswith('weight'):
        output_size, input_size = state_dict[key].shape
        if idx == 0:
          sizes.append(input_size)
        sizes.append(output_size)

    input_layer = sizes[0]
    for layer in layers:
        if layer == layers[0]:
            hidden_layers.append(layer.out_features)

        else:
            if layer == layers[-1]:
                output_layer = layer.out_features
            else:
                hidden_layers.append(layer.out_features)

        last_layer_nodes = input_layer
        nodes_up = input_layer

    g = Digraph("g", filename='visualization_tmp')
    n = 0
    g.graph_attr.update(splines="false", nodesep="0.5", ranksep="0", rankdir='LR')
    # Input Layer
    with g.subgraph(name="cluster_input") as c:
          c.attr(color="white")
          for i in range(0, sizes[0]):
              n += 1
              c.node(str(n))
              c.attr(labeljust="1")
              c.attr(label="Input Layer", labelloc="bottom")
              c.attr(rank="same")
              c.node_attr.update(
                  width="0.65",
                  style="filled",
                  shape="circle",
                  color=HAPPY_COLORS_PALETTE[3],
                  fontcolor=HAPPY_COLORS_PALETTE[3],
              )
    for layer_idx in range(0, len(sizes) - 2):
        with g.subgraph(name="cluster_" + str(layer_idx + 1)) as c:
            c.attr(color="white")
            c.attr(rank="same")
            label = f'Hidden Layer {layer_idx + 1}'
            c.attr(labeljust="right", labelloc="b", label=label)
            for j in range(0, hidden_layers[layer_idx]):
                n += 1
                c.node(
                    str(n),
                    width="0.65",
                    shape="circle",
                    style="filled",
                    color=HAPPY_COLORS_PALETTE[0],
                    fontcolor=HAPPY_COLORS_PALETTE[0],
                )
                for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                    g.edge(str(h), str(n))
            last_layer_nodes = hidden_layers[layer_idx]
            nodes_up += hidden_layers[layer_idx]

    with g.subgraph(name="cluster_output") as c:
        c.attr(color="white")
        c.attr(rank="same")
        c.attr(labeljust="1")
        for i in range(1, output_layer + 1):
            n += 1
            c.node(
                str(n),
                width="0.65",
                shape="circle",
                style="filled",
                color=HAPPY_COLORS_PALETTE[4],
                fontcolor=HAPPY_COLORS_PALETTE[4],

            )
            for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                g.edge(str(h), str(n))
        c.attr(label="Output Layer", labelloc="bottom")
        c.node_attr.update(
            color="#2ecc71", style="filled", fontcolor="#2ecc71", shape="circle"
        )

    g.attr(arrowShape="none")
    g.edge_attr.update(arrowhead="none", color="#707070", penwidth="2")
    g.view()
    return g

# %% [markdown]
# ## Define DataLoaders
#
# This code creates **data loaders** for the **MNIST dataset** using PyTorch, which handles the loading and batching of training and testing data. The **batch sizes** are set to 64 for training and 1000 for testing to balance computation efficiency and memory usage. The `train_loader` shuffles the training data for better generalization, while the `test_loader` keeps the test data in a fixed order.
#
# Both data loaders apply a series of **transformations** to the images: converting them to tensors and normalizing pixel values to have a mean of 0.1307 and a standard deviation of 0.3081. These normalization values are calculated based on the MNIST dataset and help improve model convergence during training.

# %%
# Define the Batch Sizes
batch_size_train = 64
batch_size_test = 1000

# Training DataLoader
train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

# Testing DataLoader
test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 542kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.57MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.90MB/s]

# %% [markdown]
# ### ANALYZE: Explore Common Neural Network Layers
#
# In this exercise, we explore common PyTorch layers and use them to transform an example MNIST image.
#
# Tasks:
# 1. Explore `nn.Flatten()` - Converts a multi-dimensional tensor into a single-dimensional array.
# 2. Explore `nn.Linear()`– Applies a linear transformation to the input.
# 3. Explore `nn.ReLU()`– Introduces non-linearity to the network.
# 4. Explore `nn.Sequential()`– Combines layers into a sequence.
# 5. Explore `nn.Softmax()`Converts raw scores (logits) into probabilities.

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)
input_image = images[0]
print(input_image.size())
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# #### TASK 1: nn.Flatten
#
# The `nn.Flatten()` layer reshapes a 2D image into a 1D array of pixel values. This is often the first step when using fully connected layers, as they require a flat input.

# %%
flatten = nn.Flatten()
flat_image = flatten(input_image)
print(flat_image.size())

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original image
ax[0].imshow(input_image.squeeze(), cmap='gray')
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')
ax[0].axis('off')

# Plot the flattened Image
ax[1].imshow(flat_image.detach().numpy(), cmap='gray', aspect='auto')
ax[1].set_title('Flattened Image (784 pixels)')
ax[1].set_xlabel('Pixel Index')
ax[1].set_ylabel('Pixel Value')

sns.despine()

plt.tight_layout()
plt.show()
# Out:
# torch.Size([1, 784])

# %% [markdown]
# #### TASK 2: nn.Linear
#
# The `nn.Linear()` layer applies a linear transformation to the input data using its weights and biases. This helps the network create a feature space.

# %%
layer1 = nn.Linear(in_features=28*28, out_features=20)
hidden1 = layer1(flat_image)
print(hidden1.size())

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original image
ax[0].imshow(input_image.squeeze(), cmap='gray')
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')
ax[0].axis('off')

# Hidden layer output as a bar chart
ax[1].bar(range(hidden1.size(1)), hidden1.detach().numpy().squeeze())
ax[1].set_title('Hidden Layer Output (20 features)')
ax[1].set_xlabel('Feature Index')
ax[1].set_ylabel('Feature Value')

sns.despine()

plt.tight_layout()
plt.show()
# Out:
# torch.Size([1, 20])

# %% [markdown]
# #### TASK 3: nn.ReLU
#
# The `nn.ReLU()` activation function introduces non-linearity into the model. Without non-linear functions, the network would be limited to learning only linear relationships.

# %%
hidden1_ReLU = nn.ReLU()(hidden1)

fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey = True)

# Original image
ax[0].bar(range(hidden1.size(1)), hidden1.detach().numpy().squeeze())
ax[0].set_title(f'Original Image - Label: {labels[0].item()}')

# Hidden layer output as a bar chart after ReLU
ax[1].bar(range(hidden1_ReLU.size(1)), hidden1_ReLU.detach().numpy().squeeze())
ax[1].set_title('Hidden Layer Output (ReLU Applied, 20 Features)')
ax[1].set_xlabel('Feature Index')
ax[1].set_ylabel('Feature Value')

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### TASK 4: nn.Sequential
#
# The `nn.Sequential()` module allows us to define a complete network by chaining multiple layers together. This creates a straightforward, ordered flow of data through the network.

# %%
seq_modules = nn.Sequential(
    flatten,
    layer1,
    nn.ReLU(),
    nn.Linear(20, 10)
)
logits = seq_modules(input_image)

# Capture outputs at each step
flattened = flatten(input_image)
layer1_output = layer1(flattened)
relu_output = nn.ReLU()(layer1_output)
logits = seq_modules(input_image)

# Plot the outputs
fig, axes = plt.subplots(1, 4, figsize=(15, 4))

axes[0].imshow(input_image.squeeze().numpy(), cmap='gray')
axes[0].set_title("Original Image")

axes[1].imshow(flattened.detach().numpy(), cmap='gray', aspect='auto')
axes[1].set_title("Flattened")

axes[2].bar(range(20), layer1_output.detach().numpy().squeeze())
axes[2].set_title("Layer 1 Output")

axes[3].bar(range(10), logits.detach().numpy().squeeze())
axes[3].set_title("Logits (Output)")

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### TASK 5: nn.Softmax
#
# The `nn.Softmax()` layer converts raw logits into probabilities that sum to 1. It’s typically applied to the final layer of a classification network to produce class probabilities.

# %%
# Apply Softmax to convert logits to probabilities
softmax = nn.Softmax(dim=1)
pred_probab = softmax(logits)

# Plot the logits and the resulting probabilities
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Logits (Before Softmax)
axes[0].bar(range(10), logits.squeeze().detach().numpy())
axes[0].set_title("Logits (Before Softmax)")
axes[0].set_xlabel("Class Index")
axes[0].set_ylabel("Value")

# Predicted Probabilities (After Softmax)
axes[1].bar(range(10), pred_probab.squeeze().detach().numpy())
axes[1].set_title("Predicted Probabilities (After Softmax)")
axes[1].set_xlabel("Class Index")
axes[1].set_ylabel("Probability")

sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training a Simple Convolutional Network
#
# The `train()` function is responsible for updating the network's parameters during the **training phase** using data from the training set. It sets the network to **training mode**, enabling layers like dropout that improve generalization. For **fully connected networks**, the input data is flattened into a 1D vector before being passed to the network, but this step is **skipped for convolutional neural networks (CNNs)**, which handle multi-dimensional inputs directly. During each batch, the function performs a **forward pass** to make predictions, calculates the **loss** using the Negative Log Likelihood function, and performs **backpropagation** to update the network’s weights. The function tracks and logs the **training progress** to monitor performance over time.

# %%
# Note: network.train() puts the network into "nondeterministic mode".
# This doesn't matter for the fully connected network, but it will matter for convolutional networks.
# CNNs rely on preserving spatial structure, so the nondeterministic mode can impact results.
def train(network, optimizer, epoch, trainloader, flatten_data=True):

    network.train()  # Set the network to training mode
    loss_logs = list()  # Track the loss over time

    for batch_idx, (data, target) in enumerate(trainloader):
        # For fully connected networks, we flatten the image data to feed it into the network.
        # CNNs, however, expect multi-dimensional image inputs, so we skip flattening.
        if flatten_data:
            data = flatten(data)  # Flatten the image (only for fully connected networks)

        # Move data to GPU if available
        data, target = data.to(device), target.to(device)

        # Zero the gradients from the previous batch
        optimizer.zero_grad()

        # Perform the forward pass through the network
        output = network(data)

        # Compute the loss using the Negative Log Likelihood loss function
        # This loss function is often used for classification tasks with multiple classes.
        loss = F.nll_loss(output, target)

        # Backpropagation: Calculate the gradients of the loss with respect to the network's parameters
        loss.backward()

        # Perform the optimization step: Update the network's parameters
        optimizer.step()

        # Print training progress at regular intervals
        if batch_idx % log_interval == 0:
            examples_shown = batch_idx * len(data)
            total_examples = len(trainloader.dataset)
            fraction_shown = round(examples_shown / total_examples * 100.0, 2)
            rounded_loss = round(loss.item(), 4)
            print(f'Train Epoch {epoch} Progress: {fraction_shown}%\tLoss: {rounded_loss}')

            examples_so_far = batch_idx * len(data) + epoch * len(trainloader.dataset)
            loss_logs.append((examples_so_far, loss.item()))

    return loss_logs

# %% [markdown]
# This `test()` function evaluates the performance of a trained neural network on unseen data from the test set. It puts the network into **evaluation mode** to ensure consistent behavior by disabling layers like dropout, which are only active during training. The function then loops through the test data, performs a **forward pass** to generate predictions, and calculates both the **average loss** and **accuracy**. For fully connected networks, the input data must be **flattened into a 1D vector** before being passed to the network, but this step is unnecessary for **convolutional neural networks (CNNs)**, which process multi-dimensional image data directly. The function finally prints the results, helping us assess how well the model generalizes to new data.

# %%
def test(network, flatten_data=True):
    # Set the network to evaluation mode.
    # This disables certain behaviors like dropout that are only used during training.
    network.eval()

    # Initialize test loss and correct predictions counters
    test_loss = 0
    correct = 0

    # Disable gradient calculation for efficiency since we are only testing the model.
    with torch.no_grad():
        for data, target in test_loader:
            # For fully connected networks, flatten the image data into a 1D vector.
            # CNNs expect multi-dimensional image inputs, so flattening is unnecessary for them.
            if flatten_data:
                data = flatten(data)

            # Move data and target to the GPU if available
            data, target = data.to(device), target.to(device)

            # Perform a forward pass through the network
            output = network(data)

            # Calculate the cumulative test loss using Negative Log Likelihood loss
            test_loss += F.nll_loss(output, target, size_average=False).item()

            # Get the predicted class for each input sample
            pred = output.data.max(1, keepdim=True)[1]

            # Count the number of correct predictions
            correct += pred.eq(target.data.view_as(pred)).sum()

    # Calculate the average test loss by dividing by the number of samples
    test_loss /= len(test_loader.dataset)

    # Calculate the test accuracy as a percentage
    accuracy = round(100. * correct.item() / len(test_loader.dataset), 2)

    # Print the test loss and accuracy
    print(f'\nTest set: Avg loss {round(test_loss, 4)}, Accuracy {accuracy}%\n')

    # Return the test loss and accuracy for logging purposes
    return test_loss, accuracy

# %% [markdown]
# ### EXERCISE: Define a Convolutional Neural Network
#
# Tasks:
# 1. Define a convolutional network with the following architecture.
#
#   - Define the CNN layers.
#
#     A. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second convolutional layer using `nn.Conv2d()`.
#       - Input channels = 1 (grayscale image)
#       - Output channels = 10
#       - Kernel size = 5
#
#     B. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second convolutional layer using `nn.Conv2d()`.
#       - Input channels = 10 (from the previous layer's output)
#       - Output channels = 20
#       - Kernel size = 5
#
#     C. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to add a dropout layer using `nn.Dropout2d()`.
#
#     D. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the first fully connected layer using `nn.Linear()`.
#       - Input features = 320 (flattened feature maps)
#       - Output features = 50
#
#     E. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to define the second fully connected layer using `nn.Linear()`.
#       - Input features = 50 (from the previous fully connected layer)
#       - Output features = 10 (number of classes)
#
#   - Define the forward pass of the CNN.
#
#     F. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply the first convolutional layer followed by ReLU activation and 2x2 max pooling.
#
#     G. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply the second convolutional layer followed by a dropout layer.
#
#     H. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply 2x2 max pooling to the output of the second convolutional layer.
#
#     I. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a ReLU activation to introduce non-linearity
#
#     J. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a fully connected layer with a ReLU activation.
#
#     K. Replace `<REPLACE ME AND MY ARROWS>` with the correct code to apply a fully connected layer.

# %%
# TASK 1 EXERCISE

# Define the convolutional neural network (CNN) architecture
class ConvNet(nn.Module):

    def __init__(self):
        super(ConvNet, self).__init__()

        # First convolutional layer:
        # - 1 input channel (grayscale image)
        # - 10 output channels (feature maps)
        # - 5x5 kernel size (learns 5x5 filters to detect patterns)
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5) # QUESTION A

        # Second convolutional layer:
        # - Takes 10 input feature maps from conv1
        # - Produces 20 output feature maps
        # - 5x5 kernel size
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5) # QUESTION B

        # Dropout layer to reduce overfitting by randomly dropping units during training
        self.conv2_drop = nn.Dropout2d() # QUESTION C

        # First fully connected layer:
        # - 320 input features (flattened feature maps after convolutions)
        # - 50 output features (reduces dimensionality for classification)
        self.fc1 = nn.Linear(320, 50) # QUESTION D

        # Second fully connected layer:
        # - 50 input features from the previous layer
        # - 10 output features corresponding to the number of classes
        self.fc2 = nn.Linear(50, 10) # QUESTION E
        self.Relu1 = nn.ReLU()

    def forward(self, x):
        # First convolutional layer followed by:
        # - ReLU activation (introduces non-linearity)
        # - Max pooling (reduces dimensionality by taking the max value from 2x2 regions)
        x = F.relu(F.max_pool2d(self.conv1(x), 2)) # QUESTION F

        # Second convolutional layer followed by dropout:
        # - Helps reduce overfitting by randomly dropping out units
        x = self.conv2_drop(self.conv2(x)) # QUESTION G

        # Apply max pooling to reduce the feature map size
        # - Uses a 2x2 pooling region
        x = F.max_pool2d(x, 2) # QUESTION H

        # Apply ReLU activation to introduce non-linearity
        x = F.relu(x) # QUESTION I

        # Flatten the output to a 1D vector before passing it to fully connected layers
        # - The input size is reshaped to (-1, 320), where -1 infers the batch size
        x = x.view(-1, 320)

        # Apply the first fully connected layer followed by ReLU activation
        x = F.relu(self.fc1(x))

        # Apply dropout to the fully connected layer's output to reduce overfitting
        # - Dropout is only applied during training
        x = F.dropout(x, training=self.training)

        # Apply the second fully connected layer (output layer)
        # - Produces 10 output values corresponding to class scores
        x = self.fc2(x)

        # Return the log of softmax probabilities for classification
        # - Converts the output scores into a categorical probability distribution
        return F.log_softmax(x)

# %% [markdown]
# ### EXERCISE: Train a Convolutional Neural Network with MNIST
#
# Tasks:
# 1. Set Up Your Environment and Define the Network
#   - Define key hyperparameters to control the training process.
#   - Create an instance of your CNN model using `ConvNet()`.
#   - Move the model to the appropriate device (CPU/GPU).
#   - Configure the optimizer using `optim.SGD()`.
# 2. Train Your CNN Model.
#   - Train your model for the specified number of epochs using the `train()` function.
# 3. Evaluate and Visualize the Model’s Performance.
#   - Use the `plot_results()` function to visualize:
#     - Training Loss and Test Loss Over Time
#     - Test Accuracy Over Epochs
#     - Analyze the plots to assess your model's performance.
# 4. [OPTIONAL] Experiment with changing hyperparameter values
# | Hyperparameter | Normal Range | Notes | Reference |
# | --- | --- | --- | --- |
# | Learning Rate | `1e-4` to `1` | Lower values for stability, higher for speed | [Source](https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/) |
# | Momentum | `0.85` to `0.99` | Higher values generally work better | [Source](https://www.notion.so/Explore-the-Inherent-Feature-Engineering-of-Convolutional-Neural-Networks-with-Pytorch-and-MNIST-20-2af08e5d878f80f1b081d4c99d40bf97?pvs=21) |
# | Number of Epochs | `1` to `10` | Use early stopping to avoid overfitting | [Source](https://www.notion.so/Explore-the-Inherent-Feature-Engineering-of-Convolutional-Neural-Networks-with-Pytorch-and-MNIST-20-2af08e5d878f80f1b081d4c99d40bf97?pvs=21) |

# %% [markdown]
# #### TASK 1: Prepare your Environment to Train your CNN

# %%
# TASK 1 EXERCISE

# Define hyperparameters
# Hyperparameters control the behavior of the training process.

learning_rate = 0.01  # Controls how large the weight updates are during training.
# A smaller learning rate leads to slower but more stable convergence.
# A larger learning rate can speed up convergence but may cause instability.

momentum = 0.9
# Momentum helps accelerate convergence by adding a fraction of the previous update to the current update.
# This helps the model avoid getting stuck in local minima and smooths the optimization process.

n_epochs = 2
# Number of complete passes through the training dataset during training.
# Increasing the number of epochs can improve performance, but may lead to overfitting if too high.

log_interval = 10
# How often (in batches) we print the training progress.
# For example, a log_interval of 10 means the network will print updates every 10 batches.

# Initialize the convolutional network
conv_network = ConvNet()

# Move the network to the GPU if available
conv_network.to(device)

# Define the optimizer
# We're using SGD (Stochastic Gradient Descent) with the specified learning rate and momentum.
conv_optimizer = optim.SGD(conv_network.parameters(), lr=learning_rate, momentum=momentum)

# %% [markdown]
# #### TASK 2: Train your Model

# %%
# TASK 2 EXERCISE

# Initialize lists to track test accuracy, test losses, and training losses
test_accuracies, test_losses, train_losses = list(), list(), list()
total_examples_seen = 0  # Tracks the total number of examples processed during training

# Training loop over the specified number of epochs
for epoch in range(n_epochs):

    # Run the test phase before training each epoch to log initial performance
    test_loss, test_accuracy = test(conv_network, flatten_data=False)

    # Train the network on the training dataset for the current epoch
    train_loss_logs = train(conv_network, conv_optimizer, epoch, train_loader, flatten_data=False)

    # Log test performance
    test_accuracies.append((epoch, test_accuracy))  # Log accuracy for this epoch
    test_losses.append((total_examples_seen, test_loss))  # Log test loss

    # Log training losses
    train_losses.extend(train_loss_logs)

    # Update the total number of examples seen
    total_examples_seen = train_loss_logs[-1][0]

# Final test phase after completing all epochs
test_loss, test_accuracy = test(conv_network, flatten_data=False)
test_accuracies.append((n_epochs, test_accuracy))
test_losses.append((total_examples_seen, test_loss))

# At the end of the training process, we have:
# - test_accuracies: A list tracking the model's accuracy on the test set after each epoch.
# - test_losses: A list tracking the test loss after each epoch.
# - train_losses: A detailed log of the training loss over time.
# Out:
# Test set: Avg loss 2.3206, Accuracy 10.08%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.331
# Train Epoch 0 Progress: 1.07%	Loss: 2.2842
# Train Epoch 0 Progress: 2.13%	Loss: 2.2803
# Train Epoch 0 Progress: 3.2%	Loss: 2.2263
# Train Epoch 0 Progress: 4.27%	Loss: 2.0652
# Train Epoch 0 Progress: 5.33%	Loss: 1.7672
# Train Epoch 0 Progress: 6.4%	Loss: 1.6372
# Train Epoch 0 Progress: 7.47%	Loss: 1.5887
# Train Epoch 0 Progress: 8.53%	Loss: 1.5034
# Train Epoch 0 Progress: 9.6%	Loss: 1.6417
# Train Epoch 0 Progress: 10.67%	Loss: 1.067
# Train Epoch 0 Progress: 11.73%	Loss: 1.0098
# Train Epoch 0 Progress: 12.8%	Loss: 0.8516
# Train Epoch 0 Progress: 13.87%	Loss: 0.7806
# Train Epoch 0 Progress: 14.93%	Loss: 0.8426
# Train Epoch 0 Progress: 16.0%	Loss: 0.6368
# Train Epoch 0 Progress: 17.07%	Loss: 0.6987
# Train Epoch 0 Progress: 18.13%	Loss: 0.7026
# Train Epoch 0 Progress: 19.2%	Loss: 0.6103
# Train Epoch 0 Progress: 20.27%	Loss: 0.6391
# Train Epoch 0 Progress: 21.33%	Loss: 0.4744
# Train Epoch 0 Progress: 22.4%	Loss: 0.4621
# Train Epoch 0 Progress: 23.47%	Loss: 0.4318
# Train Epoch 0 Progress: 24.53%	Loss: 0.3836
# Train Epoch 0 Progress: 25.6%	Loss: 0.5556
# Train Epoch 0 Progress: 26.67%	Loss: 0.5012
# Train Epoch 0 Progress: 27.73%	Loss: 0.3527
# Train Epoch 0 Progress: 28.8%	Loss: 0.505
# Train Epoch 0 Progress: 29.87%	Loss: 0.3288
# Train Epoch 0 Progress: 30.93%	Loss: 0.7758
# Train Epoch 0 Progress: 32.0%	Loss: 0.378
# Train Epoch 0 Progress: 33.07%	Loss: 0.609
# Train Epoch 0 Progress: 34.13%	Loss: 0.4647
# Train Epoch 0 Progress: 35.2%	Loss: 0.2422
# Train Epoch 0 Progress: 36.27%	Loss: 0.5233
# Train Epoch 0 Progress: 37.33%	Loss: 0.4926
# Train Epoch 0 Progress: 38.4%	Loss: 0.3993
# Train Epoch 0 Progress: 39.47%	Loss: 0.2441
# Train Epoch 0 Progress: 40.53%	Loss: 0.9818
# Train Epoch 0 Progress: 41.6%	Loss: 0.423
# Train Epoch 0 Progress: 42.67%	Loss: 0.4719
# Train Epoch 0 Progress: 43.73%	Loss: 0.3134
# Train Epoch 0 Progress: 44.8%	Loss: 0.5337
# Train Epoch 0 Progress: 45.87%	Loss: 0.2664
# Train Epoch 0 Progress: 46.93%	Loss: 0.5736
# Train Epoch 0 Progress: 48.0%	Loss: 0.5223
# Train Epoch 0 Progress: 49.07%	Loss: 0.429
# Train Epoch 0 Progress: 50.13%	Loss: 0.3234
# Train Epoch 0 Progress: 51.2%	Loss: 0.7012
# Train Epoch 0 Progress: 52.27%	Loss: 0.3441
# Train Epoch 0 Progress: 53.33%	Loss: 0.4634
# Train Epoch 0 Progress: 54.4%	Loss: 0.3063
# Train Epoch 0 Progress: 55.47%	Loss: 0.5831
# Train Epoch 0 Progress: 56.53%	Loss: 0.2455
# Train Epoch 0 Progress: 57.6%	Loss: 0.3912
# Train Epoch 0 Progress: 58.67%	Loss: 0.3262
# Train Epoch 0 Progress: 59.73%	Loss: 0.289
# Train Epoch 0 Progress: 60.8%	Loss: 0.2695
# Train Epoch 0 Progress: 61.87%	Loss: 0.3322
# Train Epoch 0 Progress: 62.93%	Loss: 0.2743
# Train Epoch 0 Progress: 64.0%	Loss: 0.4484
# Train Epoch 0 Progress: 65.07%	Loss: 0.3348
# Train Epoch 0 Progress: 66.13%	Loss: 0.2725
# Train Epoch 0 Progress: 67.2%	Loss: 0.4322
# Train Epoch 0 Progress: 68.27%	Loss: 0.4505
# Train Epoch 0 Progress: 69.33%	Loss: 0.4545
# Train Epoch 0 Progress: 70.4%	Loss: 0.4654
# Train Epoch 0 Progress: 71.47%	Loss: 0.2318
# Train Epoch 0 Progress: 72.53%	Loss: 0.3196
# Train Epoch 0 Progress: 73.6%	Loss: 0.3636
# Train Epoch 0 Progress: 74.67%	Loss: 0.5319
# Train Epoch 0 Progress: 75.73%	Loss: 0.324
# Train Epoch 0 Progress: 76.8%	Loss: 0.3949
# Train Epoch 0 Progress: 77.87%	Loss: 0.4256
# Train Epoch 0 Progress: 78.93%	Loss: 0.3626
# Train Epoch 0 Progress: 80.0%	Loss: 0.3911
# Train Epoch 0 Progress: 81.07%	Loss: 0.4604
# Train Epoch 0 Progress: 82.13%	Loss: 0.2509
# Train Epoch 0 Progress: 83.2%	Loss: 0.3358
# Train Epoch 0 Progress: 84.27%	Loss: 0.2383
# Train Epoch 0 Progress: 85.33%	Loss: 0.4312
# Train Epoch 0 Progress: 86.4%	Loss: 0.1924
# Train Epoch 0 Progress: 87.47%	Loss: 0.2427
# Train Epoch 0 Progress: 88.53%	Loss: 0.5002
# Train Epoch 0 Progress: 89.6%	Loss: 0.1632
# Train Epoch 0 Progress: 90.67%	Loss: 0.4005
# Train Epoch 0 Progress: 91.73%	Loss: 0.4964
# Train Epoch 0 Progress: 92.8%	Loss: 0.3748
# Train Epoch 0 Progress: 93.87%	Loss: 0.2771
# Train Epoch 0 Progress: 94.93%	Loss: 0.1459
# Train Epoch 0 Progress: 96.0%	Loss: 0.4121
# Train Epoch 0 Progress: 97.07%	Loss: 0.2146
# Train Epoch 0 Progress: 98.13%	Loss: 0.1702
# Train Epoch 0 Progress: 99.2%	Loss: 0.2194
#
# Test set: Avg loss 0.0908, Accuracy 97.25%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.2282
# Train Epoch 1 Progress: 1.07%	Loss: 0.2224
# Train Epoch 1 Progress: 2.13%	Loss: 0.3192
# Train Epoch 1 Progress: 3.2%	Loss: 0.2664
# Train Epoch 1 Progress: 4.27%	Loss: 0.6733
# Train Epoch 1 Progress: 5.33%	Loss: 0.1626
# Train Epoch 1 Progress: 6.4%	Loss: 0.39
# Train Epoch 1 Progress: 7.47%	Loss: 0.251
# Train Epoch 1 Progress: 8.53%	Loss: 0.342
# Train Epoch 1 Progress: 9.6%	Loss: 0.1906
# Train Epoch 1 Progress: 10.67%	Loss: 0.1414
# Train Epoch 1 Progress: 11.73%	Loss: 0.4338
# Train Epoch 1 Progress: 12.8%	Loss: 0.2742
# Train Epoch 1 Progress: 13.87%	Loss: 0.3784
# Train Epoch 1 Progress: 14.93%	Loss: 0.6484
# Train Epoch 1 Progress: 16.0%	Loss: 0.2131
# Train Epoch 1 Progress: 17.07%	Loss: 0.2054
# Train Epoch 1 Progress: 18.13%	Loss: 0.2704
# Train Epoch 1 Progress: 19.2%	Loss: 0.2944
# Train Epoch 1 Progress: 20.27%	Loss: 0.1961
# Train Epoch 1 Progress: 21.33%	Loss: 0.107
# Train Epoch 1 Progress: 22.4%	Loss: 0.1887
# Train Epoch 1 Progress: 23.47%	Loss: 0.2734
# Train Epoch 1 Progress: 24.53%	Loss: 0.2005
# Train Epoch 1 Progress: 25.6%	Loss: 0.283
# Train Epoch 1 Progress: 26.67%	Loss: 0.4016
# Train Epoch 1 Progress: 27.73%	Loss: 0.1801
# Train Epoch 1 Progress: 28.8%	Loss: 0.3193
# Train Epoch 1 Progress: 29.87%	Loss: 0.2385
# Train Epoch 1 Progress: 30.93%	Loss: 0.0851
# Train Epoch 1 Progress: 32.0%	Loss: 0.1605
# Train Epoch 1 Progress: 33.07%	Loss: 0.2874
# Train Epoch 1 Progress: 34.13%	Loss: 0.3619
# Train Epoch 1 Progress: 35.2%	Loss: 0.2555
# Train Epoch 1 Progress: 36.27%	Loss: 0.1592
# Train Epoch 1 Progress: 37.33%	Loss: 0.2295
# Train Epoch 1 Progress: 38.4%	Loss: 0.2733
# Train Epoch 1 Progress: 39.47%	Loss: 0.1071
# Train Epoch 1 Progress: 40.53%	Loss: 0.199
# Train Epoch 1 Progress: 41.6%	Loss: 0.3325
# Train Epoch 1 Progress: 42.67%	Loss: 0.217
# Train Epoch 1 Progress: 43.73%	Loss: 0.289
# Train Epoch 1 Progress: 44.8%	Loss: 0.2842
# Train Epoch 1 Progress: 45.87%	Loss: 0.1063
# Train Epoch 1 Progress: 46.93%	Loss: 0.1461
# Train Epoch 1 Progress: 48.0%	Loss: 0.2404
# Train Epoch 1 Progress: 49.07%	Loss: 0.112
# Train Epoch 1 Progress: 50.13%	Loss: 0.1482
# Train Epoch 1 Progress: 51.2%	Loss: 0.354
# Train Epoch 1 Progress: 52.27%	Loss: 0.2487
# Train Epoch 1 Progress: 53.33%	Loss: 0.1366
# Train Epoch 1 Progress: 54.4%	Loss: 0.3025
# Train Epoch 1 Progress: 55.47%	Loss: 0.2395
# Train Epoch 1 Progress: 56.53%	Loss: 0.3662
# Train Epoch 1 Progress: 57.6%	Loss: 0.2837
# Train Epoch 1 Progress: 58.67%	Loss: 0.2093
# Train Epoch 1 Progress: 59.73%	Loss: 0.3581
# Train Epoch 1 Progress: 60.8%	Loss: 0.3279
# Train Epoch 1 Progress: 61.87%	Loss: 0.117
# Train Epoch 1 Progress: 62.93%	Loss: 0.6033
# Train Epoch 1 Progress: 64.0%	Loss: 0.2257
# Train Epoch 1 Progress: 65.07%	Loss: 0.346
# Train Epoch 1 Progress: 66.13%	Loss: 0.2786
# Train Epoch 1 Progress: 67.2%	Loss: 0.2303
# Train Epoch 1 Progress: 68.27%	Loss: 0.3798
# Train Epoch 1 Progress: 69.33%	Loss: 0.2341
# Train Epoch 1 Progress: 70.4%	Loss: 0.1455
# Train Epoch 1 Progress: 71.47%	Loss: 0.2357
# Train Epoch 1 Progress: 72.53%	Loss: 0.1958
# Train Epoch 1 Progress: 73.6%	Loss: 0.2211
# Train Epoch 1 Progress: 74.67%	Loss: 0.3055
# Train Epoch 1 Progress: 75.73%	Loss: 0.3884
# Train Epoch 1 Progress: 76.8%	Loss: 0.2795
# Train Epoch 1 Progress: 77.87%	Loss: 0.2103
# Train Epoch 1 Progress: 78.93%	Loss: 0.1377
# Train Epoch 1 Progress: 80.0%	Loss: 0.1336
# Train Epoch 1 Progress: 81.07%	Loss: 0.2261
# Train Epoch 1 Progress: 82.13%	Loss: 0.1814
# Train Epoch 1 Progress: 83.2%	Loss: 0.2252
# Train Epoch 1 Progress: 84.27%	Loss: 0.2376
# Train Epoch 1 Progress: 85.33%	Loss: 0.3534
# Train Epoch 1 Progress: 86.4%	Loss: 0.0585
# Train Epoch 1 Progress: 87.47%	Loss: 0.1178
# Train Epoch 1 Progress: 88.53%	Loss: 0.1157
# Train Epoch 1 Progress: 89.6%	Loss: 0.1729
# Train Epoch 1 Progress: 90.67%	Loss: 0.2816
# Train Epoch 1 Progress: 91.73%	Loss: 0.1173
# Train Epoch 1 Progress: 92.8%	Loss: 0.1066
# Train Epoch 1 Progress: 93.87%	Loss: 0.3267
# Train Epoch 1 Progress: 94.93%	Loss: 0.3592
# Train Epoch 1 Progress: 96.0%	Loss: 0.187
# Train Epoch 1 Progress: 97.07%	Loss: 0.1267
# Train Epoch 1 Progress: 98.13%	Loss: 0.1925
# Train Epoch 1 Progress: 99.2%	Loss: 0.2572
#
# Test set: Avg loss 0.0619, Accuracy 97.86%

# %% [markdown]
# #### TASK 3: Assess the Performance of your Model

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_results(test_accuracies, test_losses, train_losses):
    """
    Plot training losses, test losses, and test accuracy over time.

    Parameters:
    - test_accuracies: List of tuples [(epoch, accuracy)], representing test accuracy over epochs.
    - test_losses: List of tuples [(epoch, loss)], representing test loss over examples seen.
    - train_losses: List of tuples [(example, loss)], representing training loss over examples seen.
    """
    # --- Plot Training and Test Losses ---
    plt.figure(figsize=(12, 6))

    # Extract values for training losses
    train_x, train_y = zip(*train_losses)

    # Extract values for test losses
    test_x, test_y = zip(*test_losses)

    # Plot training losses
    plt.plot(train_x, train_y, label='Training Loss', color='b', linestyle='-', marker='.')

    # Plot test losses
    plt.plot(test_x, test_y, label='Test Loss', color='r', linestyle='--', marker='o')

    # Formatting
    plt.xlabel('Examples Seen')
    plt.ylabel('Log Loss')
    plt.title('Training and Test Losses Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

    # --- Plot Test Accuracy ---
    plt.figure(figsize=(12, 6))

    # Extract values for test accuracy
    acc_x, acc_y = zip(*test_accuracies)

    # Plot test accuracy
    plt.plot(acc_x, acc_y, label='Test Accuracy', color='g', marker='o')

    # Formatting
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy Over Epochs')
    plt.legend()
    plt.grid(True)
    sns.despine()
    plt.show()

# %%
# TASK 3 EXERCISE

# Plot your Results using the function `plot_resolts
#''' ADD YOUR CODE HERE '''
plot_results(test_accuracies, test_losses, train_losses)

# %%
class FullyConnectedNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28 * 28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        self.drop = nn.Dropout(0.5)

    def forward(self, x):
        x = x.view(x.size(0), -1)   # flatten
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
# Initialize the fully connnected network
fcnn = FullyConnectedNetwork()

# Move the network to the GPU if available
fcnn.to(device)

# Define the optimizer
# We're using SGD (Stochastic Gradient Descent) with the specified learning rate and momentum.
fc_optimizer = optim.SGD(fcnn.parameters(), lr=learning_rate, momentum=momentum)

# %%
# Initialize lists to track test accuracy, test losses, and training losses
test_accuracies, test_losses, train_losses = list(), list(), list()
total_examples_seen = 0  # Tracks the total number of examples processed during training

# Training loop over the specified number of epochs
for epoch in range(n_epochs):

    # Run the test phase before training each epoch to log initial performance
    test_loss, test_accuracy = test(fcnn, flatten_data=True)

    # Train the network on the training dataset for the current epoch
    train_loss_logs = train(fcnn, fc_optimizer, epoch, train_loader, flatten_data=True)

    # Log test performance
    test_accuracies.append((epoch, test_accuracy))  # Log accuracy for this epoch
    test_losses.append((total_examples_seen, test_loss))  # Log test loss

    # Log training losses
    train_losses.extend(train_loss_logs)

    # Update the total number of examples seen
    total_examples_seen = train_loss_logs[-1][0]

# Final test phase after completing all epochs
test_loss, test_accuracy = test(fcnn, flatten_data=True)
test_accuracies.append((n_epochs, test_accuracy))
test_losses.append((total_examples_seen, test_loss))

# At the end of the training process, we have:
# - test_accuracies: A list tracking the model's accuracy on the test set after each epoch.
# - test_losses: A list tracking the test loss after each epoch.
# - train_losses: A detailed log of the training loss over time.
# Out:
# Test set: Avg loss 2.3, Accuracy 10.81%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3022
# Train Epoch 0 Progress: 1.07%	Loss: 2.1896
# Train Epoch 0 Progress: 2.13%	Loss: 1.9198
# Train Epoch 0 Progress: 3.2%	Loss: 1.3955
# Train Epoch 0 Progress: 4.27%	Loss: 0.8541
# Train Epoch 0 Progress: 5.33%	Loss: 0.5984
# Train Epoch 0 Progress: 6.4%	Loss: 0.7752
# Train Epoch 0 Progress: 7.47%	Loss: 0.3888
# Train Epoch 0 Progress: 8.53%	Loss: 0.5608
# Train Epoch 0 Progress: 9.6%	Loss: 0.5426
# Train Epoch 0 Progress: 10.67%	Loss: 0.5913
# Train Epoch 0 Progress: 11.73%	Loss: 0.4889
# Train Epoch 0 Progress: 12.8%	Loss: 0.2809
# Train Epoch 0 Progress: 13.87%	Loss: 0.2467
# Train Epoch 0 Progress: 14.93%	Loss: 0.4479
# Train Epoch 0 Progress: 16.0%	Loss: 0.299
# Train Epoch 0 Progress: 17.07%	Loss: 0.4183
# Train Epoch 0 Progress: 18.13%	Loss: 0.3789
# Train Epoch 0 Progress: 19.2%	Loss: 0.3557
# Train Epoch 0 Progress: 20.27%	Loss: 0.1407
# Train Epoch 0 Progress: 21.33%	Loss: 0.2491
# Train Epoch 0 Progress: 22.4%	Loss: 0.435
# Train Epoch 0 Progress: 23.47%	Loss: 0.4327
# Train Epoch 0 Progress: 24.53%	Loss: 0.3535
# Train Epoch 0 Progress: 25.6%	Loss: 0.2604
# Train Epoch 0 Progress: 26.67%	Loss: 0.2872
# Train Epoch 0 Progress: 27.73%	Loss: 0.2721
# Train Epoch 0 Progress: 28.8%	Loss: 0.4118
# Train Epoch 0 Progress: 29.87%	Loss: 0.2745
# Train Epoch 0 Progress: 30.93%	Loss: 0.4441
# Train Epoch 0 Progress: 32.0%	Loss: 0.3617
# Train Epoch 0 Progress: 33.07%	Loss: 0.1981
# Train Epoch 0 Progress: 34.13%	Loss: 0.1284
# Train Epoch 0 Progress: 35.2%	Loss: 0.3407
# Train Epoch 0 Progress: 36.27%	Loss: 0.407
# Train Epoch 0 Progress: 37.33%	Loss: 0.3565
# Train Epoch 0 Progress: 38.4%	Loss: 0.25
# Train Epoch 0 Progress: 39.47%	Loss: 0.2807
# Train Epoch 0 Progress: 40.53%	Loss: 0.2626
# Train Epoch 0 Progress: 41.6%	Loss: 0.4391
# Train Epoch 0 Progress: 42.67%	Loss: 0.2704
# Train Epoch 0 Progress: 43.73%	Loss: 0.2056
# Train Epoch 0 Progress: 44.8%	Loss: 0.2225
# Train Epoch 0 Progress: 45.87%	Loss: 0.2037
# Train Epoch 0 Progress: 46.93%	Loss: 0.2423
# Train Epoch 0 Progress: 48.0%	Loss: 0.2386
# Train Epoch 0 Progress: 49.07%	Loss: 0.3602
# Train Epoch 0 Progress: 50.13%	Loss: 0.1601
# Train Epoch 0 Progress: 51.2%	Loss: 0.1901
# Train Epoch 0 Progress: 52.27%	Loss: 0.4193
# Train Epoch 0 Progress: 53.33%	Loss: 0.3347
# Train Epoch 0 Progress: 54.4%	Loss: 0.1279
# Train Epoch 0 Progress: 55.47%	Loss: 0.1131
# Train Epoch 0 Progress: 56.53%	Loss: 0.2101
# Train Epoch 0 Progress: 57.6%	Loss: 0.2813
# Train Epoch 0 Progress: 58.67%	Loss: 0.2328
# Train Epoch 0 Progress: 59.73%	Loss: 0.2861
# Train Epoch 0 Progress: 60.8%	Loss: 0.169
# Train Epoch 0 Progress: 61.87%	Loss: 0.1857
# Train Epoch 0 Progress: 62.93%	Loss: 0.3454
# Train Epoch 0 Progress: 64.0%	Loss: 0.1146
# Train Epoch 0 Progress: 65.07%	Loss: 0.2431
# Train Epoch 0 Progress: 66.13%	Loss: 0.1404
# Train Epoch 0 Progress: 67.2%	Loss: 0.2599
# Train Epoch 0 Progress: 68.27%	Loss: 0.1506
# Train Epoch 0 Progress: 69.33%	Loss: 0.3212
# Train Epoch 0 Progress: 70.4%	Loss: 0.1672
# Train Epoch 0 Progress: 71.47%	Loss: 0.1647
# Train Epoch 0 Progress: 72.53%	Loss: 0.2312
# Train Epoch 0 Progress: 73.6%	Loss: 0.2165
# Train Epoch 0 Progress: 74.67%	Loss: 0.1326
# Train Epoch 0 Progress: 75.73%	Loss: 0.2869
# Train Epoch 0 Progress: 76.8%	Loss: 0.2455
# Train Epoch 0 Progress: 77.87%	Loss: 0.283
# Train Epoch 0 Progress: 78.93%	Loss: 0.3978
# Train Epoch 0 Progress: 80.0%	Loss: 0.0574
# Train Epoch 0 Progress: 81.07%	Loss: 0.197
# Train Epoch 0 Progress: 82.13%	Loss: 0.2272
# Train Epoch 0 Progress: 83.2%	Loss: 0.2717
# Train Epoch 0 Progress: 84.27%	Loss: 0.1333
# Train Epoch 0 Progress: 85.33%	Loss: 0.2589
# Train Epoch 0 Progress: 86.4%	Loss: 0.1111
# Train Epoch 0 Progress: 87.47%	Loss: 0.2184
# Train Epoch 0 Progress: 88.53%	Loss: 0.2628
# Train Epoch 0 Progress: 89.6%	Loss: 0.2138
# Train Epoch 0 Progress: 90.67%	Loss: 0.0802
# Train Epoch 0 Progress: 91.73%	Loss: 0.0623
# Train Epoch 0 Progress: 92.8%	Loss: 0.1082
# Train Epoch 0 Progress: 93.87%	Loss: 0.1408
# Train Epoch 0 Progress: 94.93%	Loss: 0.1504
# Train Epoch 0 Progress: 96.0%	Loss: 0.2228
# Train Epoch 0 Progress: 97.07%	Loss: 0.1408
# Train Epoch 0 Progress: 98.13%	Loss: 0.2025
# Train Epoch 0 Progress: 99.2%	Loss: 0.0756
#
# Test set: Avg loss 0.1323, Accuracy 95.74%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.1272
# Train Epoch 1 Progress: 1.07%	Loss: 0.229
# Train Epoch 1 Progress: 2.13%	Loss: 0.1628
# Train Epoch 1 Progress: 3.2%	Loss: 0.2176
# Train Epoch 1 Progress: 4.27%	Loss: 0.1921
# Train Epoch 1 Progress: 5.33%	Loss: 0.2031
# Train Epoch 1 Progress: 6.4%	Loss: 0.2506
# Train Epoch 1 Progress: 7.47%	Loss: 0.1791
# Train Epoch 1 Progress: 8.53%	Loss: 0.1133
# Train Epoch 1 Progress: 9.6%	Loss: 0.2855
# Train Epoch 1 Progress: 10.67%	Loss: 0.2703
# Train Epoch 1 Progress: 11.73%	Loss: 0.251
# Train Epoch 1 Progress: 12.8%	Loss: 0.3824
# Train Epoch 1 Progress: 13.87%	Loss: 0.1261
# Train Epoch 1 Progress: 14.93%	Loss: 0.147
# Train Epoch 1 Progress: 16.0%	Loss: 0.3408
# Train Epoch 1 Progress: 17.07%	Loss: 0.2118
# Train Epoch 1 Progress: 18.13%	Loss: 0.1658
# Train Epoch 1 Progress: 19.2%	Loss: 0.217
# Train Epoch 1 Progress: 20.27%	Loss: 0.2181
# Train Epoch 1 Progress: 21.33%	Loss: 0.254
# Train Epoch 1 Progress: 22.4%	Loss: 0.0899
# Train Epoch 1 Progress: 23.47%	Loss: 0.0512
# Train Epoch 1 Progress: 24.53%	Loss: 0.1658
# Train Epoch 1 Progress: 25.6%	Loss: 0.1089
# Train Epoch 1 Progress: 26.67%	Loss: 0.0712
# Train Epoch 1 Progress: 27.73%	Loss: 0.3287
# Train Epoch 1 Progress: 28.8%	Loss: 0.2242
# Train Epoch 1 Progress: 29.87%	Loss: 0.3103
# Train Epoch 1 Progress: 30.93%	Loss: 0.1984
# Train Epoch 1 Progress: 32.0%	Loss: 0.1485
# Train Epoch 1 Progress: 33.07%	Loss: 0.1736
# Train Epoch 1 Progress: 34.13%	Loss: 0.2054
# Train Epoch 1 Progress: 35.2%	Loss: 0.1588
# Train Epoch 1 Progress: 36.27%	Loss: 0.1188
# Train Epoch 1 Progress: 37.33%	Loss: 0.023
# Train Epoch 1 Progress: 38.4%	Loss: 0.1648
# Train Epoch 1 Progress: 39.47%	Loss: 0.2099
# Train Epoch 1 Progress: 40.53%	Loss: 0.1679
# Train Epoch 1 Progress: 41.6%	Loss: 0.2319
# Train Epoch 1 Progress: 42.67%	Loss: 0.1025
# Train Epoch 1 Progress: 43.73%	Loss: 0.0499
# Train Epoch 1 Progress: 44.8%	Loss: 0.0631
# Train Epoch 1 Progress: 45.87%	Loss: 0.0282
# Train Epoch 1 Progress: 46.93%	Loss: 0.0622
# Train Epoch 1 Progress: 48.0%	Loss: 0.0657
# Train Epoch 1 Progress: 49.07%	Loss: 0.198
# Train Epoch 1 Progress: 50.13%	Loss: 0.1824
# Train Epoch 1 Progress: 51.2%	Loss: 0.2708
# Train Epoch 1 Progress: 52.27%	Loss: 0.1082
# Train Epoch 1 Progress: 53.33%	Loss: 0.0908
# Train Epoch 1 Progress: 54.4%	Loss: 0.1005
# Train Epoch 1 Progress: 55.47%	Loss: 0.1216
# Train Epoch 1 Progress: 56.53%	Loss: 0.1988
# Train Epoch 1 Progress: 57.6%	Loss: 0.0501
# Train Epoch 1 Progress: 58.67%	Loss: 0.1067
# Train Epoch 1 Progress: 59.73%	Loss: 0.2189
# Train Epoch 1 Progress: 60.8%	Loss: 0.1602
# Train Epoch 1 Progress: 61.87%	Loss: 0.1525
# Train Epoch 1 Progress: 62.93%	Loss: 0.0734
# Train Epoch 1 Progress: 64.0%	Loss: 0.0869
# Train Epoch 1 Progress: 65.07%	Loss: 0.1472
# Train Epoch 1 Progress: 66.13%	Loss: 0.0493
# Train Epoch 1 Progress: 67.2%	Loss: 0.1188
# Train Epoch 1 Progress: 68.27%	Loss: 0.2863
# Train Epoch 1 Progress: 69.33%	Loss: 0.2348
# Train Epoch 1 Progress: 70.4%	Loss: 0.0495
# Train Epoch 1 Progress: 71.47%	Loss: 0.349
# Train Epoch 1 Progress: 72.53%	Loss: 0.1717
# Train Epoch 1 Progress: 73.6%	Loss: 0.205
# Train Epoch 1 Progress: 74.67%	Loss: 0.0469
# Train Epoch 1 Progress: 75.73%	Loss: 0.115
# Train Epoch 1 Progress: 76.8%	Loss: 0.1633
# Train Epoch 1 Progress: 77.87%	Loss: 0.1028
# Train Epoch 1 Progress: 78.93%	Loss: 0.3448
# Train Epoch 1 Progress: 80.0%	Loss: 0.2146
# Train Epoch 1 Progress: 81.07%	Loss: 0.0787
# Train Epoch 1 Progress: 82.13%	Loss: 0.1981
# Train Epoch 1 Progress: 83.2%	Loss: 0.0432
# Train Epoch 1 Progress: 84.27%	Loss: 0.0957
# Train Epoch 1 Progress: 85.33%	Loss: 0.1366
# Train Epoch 1 Progress: 86.4%	Loss: 0.0846
# Train Epoch 1 Progress: 87.47%	Loss: 0.0568
# Train Epoch 1 Progress: 88.53%	Loss: 0.1472
# Train Epoch 1 Progress: 89.6%	Loss: 0.1458
# Train Epoch 1 Progress: 90.67%	Loss: 0.1832
# Train Epoch 1 Progress: 91.73%	Loss: 0.1232
# Train Epoch 1 Progress: 92.8%	Loss: 0.2203
# Train Epoch 1 Progress: 93.87%	Loss: 0.0275
# Train Epoch 1 Progress: 94.93%	Loss: 0.1492
# Train Epoch 1 Progress: 96.0%	Loss: 0.1643
# Train Epoch 1 Progress: 97.07%	Loss: 0.0845
# Train Epoch 1 Progress: 98.13%	Loss: 0.0521
# Train Epoch 1 Progress: 99.2%	Loss: 0.1381
#
# Test set: Avg loss 0.0947, Accuracy 97.05%

# %%
plot_results(test_accuracies, test_losses, train_losses)

# %% [markdown]
# ## What is Learned in Convolutional Neural Networks?
#
# The following code contains a function called `preprocess_random_mnist_image` that extracts a random image from an MNIST-style dataset using a `DataLoader`, applies preprocessing transformations, and returns a ready-to-use tensor for model input.
#
# This function is designed to streamline the process of preparing an MNIST image for neural network inference by handling the following tasks:
#
# 1. **Data Extraction**: It pulls image data from a `DataLoader` object, which typically wraps around an MNIST dataset.
# 2. **Random Selection**: It selects a random image from the dataset, simulating a dynamic testing scenario.
# 3. **Image Conversion**: The selected image is converted from a NumPy array to a PIL image, ensuring compatibility with common image transformation tools.
# 4. **Preprocessing**: The image undergoes a series of transformations:
#    - Converted to a tensor using `transforms.ToTensor()`.
#    - Normalized using the standard mean and standard deviation of the MNIST dataset (`mean=0.1307`, `std=0.3081`).
# 5. **Batch Formatting**: The processed tensor is reshaped to include a batch dimension, resulting in a tensor of shape `[1, 1, H, W]` — the expected input format for most deep learning models.

# %%
import numpy as np
from PIL import Image
from torchvision import transforms

def preprocess_random_mnist_image(data_loader, mnist_mean=0.1307, mnist_std=0.3081):
    """
    Extracts a random image from a DataLoader, preprocesses it using MNIST dataset mean and std,
    and returns a batch tensor ready for model input.

    Parameters:
    - data_loader: DataLoader containing the dataset (assumes MNIST format with .data attribute).
    - mnist_mean: Mean value for normalization (default is MNIST mean 0.1307).
    - mnist_std: Standard deviation for normalization (default is MNIST std 0.3081).

    Returns:
    - input_image: A torch tensor of shape [1, 1, H, W], ready for model input.
    """
    # Extract dataset from the DataLoader
    dataset = np.array(data_loader.dataset.data)  # Assuming the DataLoader is for MNIST
    num_images = dataset.shape[0]

    # Randomly select an image
    image_idx = np.random.randint(low=0, high=num_images)
    selected_image = dataset[image_idx]  # Shape: [H, W]

    # Convert to PIL image for consistency
    pil_image = Image.fromarray(selected_image)

    # Define preprocessing transforms
    preprocess = transforms.Compose([
        transforms.ToTensor(),       # Converts [H, W] to [1, H, W] and scales to [0, 1]
        transforms.Normalize(mean=[mnist_mean], std=[mnist_std])  # Normalize using MNIST stats
    ])

    # Apply preprocessing
    input_tensor = preprocess(pil_image)  # Shape: [1, H, W]

    # Add batch dimension to match model input requirements
    input_image = input_tensor.unsqueeze(0)  # Shape: [1, 1, H, W]

    return input_image

# %% [markdown]
# ### ANALYZE: Explore What is Learned in CNNs
#
# Tasks:
# 1. Visualize Convolutional Filters/Weights
#   - In this task, you will visualize the filters (weights) learned by the first convolutional layer of a trained CNN model. Filters represent the patterns that the model detects from the input images.
#     - Pass your trained model and the name of the first convolutional layer to the function, `visualize_filters_pytorch()`.
# 2. Visualize Feature Maps
#   - Feature maps represent the intermediate outputs generated by the CNN at each layer after applying the filters to an input image.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `visualize_feature_maps_pytorch()` to visualize the feature maps for a specific layer.
# 3. Generate Saliency Maps
#   - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Call the function `generate_saliency_map_pytorch()` to generate a saliency map for a given class index.
# 4. Generate Class Activation Maps (CAMs)
#   - Class Activation Maps (CAMs) show which regions of an input image are most relevant to a specific class prediction by the model.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `generate_cam_pytorch()` to generate a CAM for a given class index and layer.

# %% [markdown]
# #### TASK 1: Convolutional Filters/Weights
#
#   - In this task, you will visualize the filters (weights) learned by the first convolutional layer of a trained CNN model. Filters represent the patterns that the model detects from the input images.
#     - Pass your trained model and the name of the first convolutional layer to the function, `visualize_filters_pytorch()`.

# %%
# --------------------------------------------
# FILTER VISUALIZATION
# --------------------------------------------

def visualize_filters_pytorch(model, layer_name):
    """
    Visualize filters from a specific convolutional layer in a PyTorch model.

    Parameters:
    - model: Trained PyTorch model.
    - layer_name: Name of the convolutional layer to visualize.
    """
    # Extract the layer's weights
    layer = dict(model.named_modules())[layer_name]
    weights = layer.weight.data.cpu().numpy()

    # Normalize the filters to 0-1 for visualization
    filters = (weights - weights.min()) / (weights.max() - weights.min())

    num_filters = filters.shape[0]
    num_columns = 8
    num_rows = int(np.ceil(num_filters / num_columns))

    plt.figure(figsize=(num_columns * 2, num_rows * 2))
    for i in range(num_filters):
        plt.subplot(num_rows, num_columns, i + 1)
        plt.imshow(filters[i, 0, :, :], cmap="viridis")
        plt.axis("off")
    plt.suptitle(f"Filters in layer: {layer_name}", fontsize=16)
    plt.show()

# %%
# TASK 1 EXERCISE

# Visualize Filters/Weights of your Trained Model
#''' ADD YOUR CODE HERE '''
visualize_filters_pytorch(conv_network, 'conv1')

# %% [markdown]
# #### TASK 2: Feature Maps
#
#   - Feature maps represent the intermediate outputs generated by the CNN at each layer after applying the filters to an input image.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `visualize_feature_maps_pytorch()` to visualize the feature maps for a specific layer.

# %%
# --------------------------------------------
# FEATURE MAP VISUALIZATION
# --------------------------------------------

def visualize_feature_maps_pytorch(model, layer_name, input_image):
    """
    Visualize feature maps from a specific layer in a PyTorch model.

    Parameters:
    - model: Trained PyTorch model.
    - layer_name: Name of the layer to visualize.
    - input_image: Input image tensor (should be preprocessed and have shape [1, C, H, W]).
    """

    model.eval()
    hooks = []

    # Hook to capture the output of the specified layer
    def hook_fn(module, input, output):
        hooks.append(output)

    layer = dict(model.named_modules())[layer_name]
    handle = layer.register_forward_hook(hook_fn)

    # Forward pass to get the feature maps
    with torch.no_grad():
        model(input_image)

    # Detach the output and convert to numpy
    feature_maps = hooks[0].detach().cpu().numpy()[0]

    num_maps = feature_maps.shape[0]
    num_columns = 8
    num_rows = int(np.ceil(num_maps / num_columns))

    plt.figure(figsize=(num_columns * 2, num_rows * 2))
    for i in range(num_maps):
        plt.subplot(num_rows, num_columns, i + 1)
        plt.imshow(feature_maps[i, :, :], cmap="viridis")
        plt.axis("off")
    plt.suptitle(f"Feature maps in layer: {layer_name}", fontsize=16)
    plt.show()

    # Clean up the hook
    handle.remove()

# %%
# TASK 2 EXERCISE

# Preprocess an image from the `train_loader` using ``preprocess_random_mnist_image(~)`
input_image = preprocess_random_mnist_image(train_loader)

# Visualize feature maps
#''' ADD YOUR CODE HERE '''
visualize_feature_maps_pytorch(conv_network, 'conv1', input_image)

# %% [markdown]
# #### TASK 3:  Saliency Maps
#
#   - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Call the function `generate_saliency_map_pytorch()` to generate a saliency map for a given class index.

# %%
# --------------------------------------------
# SALIENCY MAP GENERATION
# --------------------------------------------

def generate_saliency_map_pytorch(model, input_image, class_idx):
    """
    Generate a saliency map for a given input image and class index.

    Parameters:
    - model: Trained PyTorch model.
    - input_image: Input image tensor (requires_grad=True, shape [1, C, H, W]).
    - class_idx: Class index to compute saliency for.
    """
    model.eval()
    input_image.requires_grad_()

    # Forward pass
    output = model(input_image)
    class_score = output[0, class_idx]

    # Backward pass to compute gradients
    class_score.backward()

    # Get the gradients and normalize
    saliency = input_image.grad.data.abs().squeeze().cpu().numpy()
    saliency = (saliency - saliency.min()) / (saliency.max() - saliency.min())

    # Plot the saliency map
    plt.figure(figsize=(8, 8))
    plt.imshow(saliency, cmap="hot")
    plt.axis("off")
    plt.title("Saliency Map")
    plt.show()

# %%
# TASK 3 EXERCISE

# Preprocess an image from the `train_loader` using ``preprocess_random_mnist_image(~)`
input_image = preprocess_random_mnist_image(train_loader)

# Visualize saliency maps
#''' ADD YOUR CODE HERE '''

generate_saliency_map_pytorch(conv_network, input_image, class_idx=5)

# %% [markdown]
# #### TASK 4: Class Activation Maps (CAM)
#
#   - Class Activation Maps (CAMs) show which regions of an input image are most relevant to a specific class prediction by the model.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `generate_cam_pytorch()` to generate a CAM for a given class index and layer.

# %%
# --------------------------------------------
# CLASS ACTIVATION MAP (CAM) GENERATION
# --------------------------------------------

def generate_cam_pytorch(model, target_layer_name, input_image, class_idx):
    """
    Generate a Class Activation Map (CAM) for a given input image and class index.

    Parameters:
    - model: Trained PyTorch model.
    - target_layer_name: Name of the target convolutional layer.
    - input_image: Input image tensor (should be preprocessed and have shape [1, C, H, W]).
    - class_idx: Class index to compute CAM for.
    """
    model.eval()

    # Store the feature maps and gradients
    feature_maps = []
    gradients = []

    # Hook to capture the feature maps
    def forward_hook(module, input, output):
        feature_maps.append(output)

    # Hook to capture the gradients
    def backward_hook(module, grad_in, grad_out):
        gradients.append(grad_out[0])

    # Register hooks
    target_layer = dict(model.named_modules())[target_layer_name]
    forward_handle = target_layer.register_forward_hook(forward_hook)
    backward_handle = target_layer.register_backward_hook(backward_hook)

    # Forward pass
    output = model(input_image)
    class_score = output[0, class_idx]

    # Backward pass
    model.zero_grad()
    class_score.backward()

    # Get feature maps and gradients
    fmap = feature_maps[0].squeeze(0).detach().cpu().numpy()
    grad = gradients[0].squeeze(0).detach().cpu().numpy()

    # Compute the weighted sum of feature maps
    weights = np.mean(grad, axis=(1, 2))  # Global average pooling on gradients
    cam = np.zeros(fmap.shape[1:], dtype=np.float32)

    for i, w in enumerate(weights):
        cam += w * fmap[i]

    # Normalize CAM to 0-1
    cam = np.maximum(cam, 0)
    cam = (cam - cam.min()) / (cam.max() - cam.min())

    # Plot the CAM
    plt.figure(figsize=(8, 8))
    plt.imshow(cam, cmap="jet")
    plt.axis("off")
    plt.title(f"Class Activation Map (CAM) for Class {class_idx}")
    plt.show()

    # Clean up hooks
    forward_handle.remove()
    backward_handle.remove()

# %%
# TASK 4 EXERCISE

# Preprocess an image from the `train_loader` using ``preprocess_random_mnist_image(~)`
input_image = preprocess_random_mnist_image(train_loader)

# Visualize class activation maps
#''' ADD YOUR CODE HERE '''
generate_cam_pytorch(conv_network, 'conv2', input_image, class_idx=5)

# %% [markdown]
# # Appendices

# %% [markdown]
# ## Hyperparameter Tuning with CNNs

# %% [markdown]
# ### EXERCISE: Perform Hyperparameter Tuning to Improve Performance of your Convolutional Neural Network

# %%
from itertools import product

# Define ranges for hyperparameters
learning_rates = [0.001, 0.01, 0.1]
momentums = [0.5, 0.9]
batch_sizes = [32, 64, 128]

# Store results
results = []

# Hyperparameter tuning loop
for lr, momentum, batch_size in product(learning_rates, momentums, batch_sizes):
    print(f"Training with lr={lr}, momentum={momentum}, batch_size={batch_size}")

    # Update train loader with the current batch size
    train_loader = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST('sample_data/', train=True, download=True,
                                   transform=torchvision.transforms.Compose([
                                       torchvision.transforms.ToTensor(),
                                       torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                   ])),
        batch_size=batch_size, shuffle=True)

    # Initialize network
    conv_network = ConvNet()
    conv_network.to(device)

    # Define optimizer
    conv_optimizer = optim.SGD(conv_network.parameters(), lr=lr, momentum=momentum)

    # Train and test
    test_accuracies, test_losses, train_losses = list(), list(), list()
    total_examples_seen = 0
    for epoch in range(n_epochs):
        test_loss, test_accuracy = test(conv_network, flatten_data=False)
        train_loss_logs = train(conv_network, conv_optimizer, epoch, train_loader, flatten_data=False)
        test_accuracies.append((epoch, test_accuracy))
        test_losses.append((total_examples_seen, test_loss))
        train_losses.extend(train_loss_logs)
        total_examples_seen = train_loss_logs[-1][0]
    test_loss, test_accuracy = test(conv_network, flatten_data=False)

    # Log the performance
    results.append({
        "lr": lr,
        "momentum": momentum,
        "batch_size": batch_size,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy
    })
# Out:
# Training with lr=0.001, momentum=0.5, batch_size=32
#
# Test set: Avg loss 2.3076, Accuracy 9.97%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3473
# Train Epoch 0 Progress: 0.53%	Loss: 2.3585
# Train Epoch 0 Progress: 1.07%	Loss: 2.2645
# Train Epoch 0 Progress: 1.6%	Loss: 2.3296
# Train Epoch 0 Progress: 2.13%	Loss: 2.355
# Train Epoch 0 Progress: 2.67%	Loss: 2.2843
# Train Epoch 0 Progress: 3.2%	Loss: 2.326
# Train Epoch 0 Progress: 3.73%	Loss: 2.2779
# Train Epoch 0 Progress: 4.27%	Loss: 2.3381
# Train Epoch 0 Progress: 4.8%	Loss: 2.2968
# Train Epoch 0 Progress: 5.33%	Loss: 2.2572
# Train Epoch 0 Progress: 5.87%	Loss: 2.3153
# Train Epoch 0 Progress: 6.4%	Loss: 2.3487
# Train Epoch 0 Progress: 6.93%	Loss: 2.2461
# Train Epoch 0 Progress: 7.47%	Loss: 2.2637
# Train Epoch 0 Progress: 8.0%	Loss: 2.2968
# Train Epoch 0 Progress: 8.53%	Loss: 2.3245
# Train Epoch 0 Progress: 9.07%	Loss: 2.299
# Train Epoch 0 Progress: 9.6%	Loss: 2.3076
# Train Epoch 0 Progress: 10.13%	Loss: 2.272
# Train Epoch 0 Progress: 10.67%	Loss: 2.3148
# Train Epoch 0 Progress: 11.2%	Loss: 2.2376
# Train Epoch 0 Progress: 11.73%	Loss: 2.2877
# Train Epoch 0 Progress: 12.27%	Loss: 2.2669
# Train Epoch 0 Progress: 12.8%	Loss: 2.2553
# Train Epoch 0 Progress: 13.33%	Loss: 2.2783
# Train Epoch 0 Progress: 13.87%	Loss: 2.289
# Train Epoch 0 Progress: 14.4%	Loss: 2.2728
# Train Epoch 0 Progress: 14.93%	Loss: 2.2252
# Train Epoch 0 Progress: 15.47%	Loss: 2.2093
# Train Epoch 0 Progress: 16.0%	Loss: 2.2716
# Train Epoch 0 Progress: 16.53%	Loss: 2.2424
# Train Epoch 0 Progress: 17.07%	Loss: 2.2825
# Train Epoch 0 Progress: 17.6%	Loss: 2.2807
# Train Epoch 0 Progress: 18.13%	Loss: 2.2365
# Train Epoch 0 Progress: 18.67%	Loss: 2.2307
# Train Epoch 0 Progress: 19.2%	Loss: 2.2598
# Train Epoch 0 Progress: 19.73%	Loss: 2.2658
# Train Epoch 0 Progress: 20.27%	Loss: 2.1941
# Train Epoch 0 Progress: 20.8%	Loss: 2.2026
# Train Epoch 0 Progress: 21.33%	Loss: 2.2017
# Train Epoch 0 Progress: 21.87%	Loss: 2.271
# Train Epoch 0 Progress: 22.4%	Loss: 2.2955
# Train Epoch 0 Progress: 22.93%	Loss: 2.2961
# Train Epoch 0 Progress: 23.47%	Loss: 2.2588
# Train Epoch 0 Progress: 24.0%	Loss: 2.2718
# Train Epoch 0 Progress: 24.53%	Loss: 2.2619
# Train Epoch 0 Progress: 25.07%	Loss: 2.2235
# Train Epoch 0 Progress: 25.6%	Loss: 2.2267
# Train Epoch 0 Progress: 26.13%	Loss: 2.2167
# Train Epoch 0 Progress: 26.67%	Loss: 2.1758
# Train Epoch 0 Progress: 27.2%	Loss: 2.1865
# Train Epoch 0 Progress: 27.73%	Loss: 2.2358
# Train Epoch 0 Progress: 28.27%	Loss: 2.235
# Train Epoch 0 Progress: 28.8%	Loss: 2.178
# Train Epoch 0 Progress: 29.33%	Loss: 2.2375
# Train Epoch 0 Progress: 29.87%	Loss: 2.1709
# Train Epoch 0 Progress: 30.4%	Loss: 2.2231
# Train Epoch 0 Progress: 30.93%	Loss: 2.1713
# Train Epoch 0 Progress: 31.47%	Loss: 2.16
# Train Epoch 0 Progress: 32.0%	Loss: 2.1836
# Train Epoch 0 Progress: 32.53%	Loss: 2.1773
# Train Epoch 0 Progress: 33.07%	Loss: 2.225
# Train Epoch 0 Progress: 33.6%	Loss: 2.1689
# Train Epoch 0 Progress: 34.13%	Loss: 2.162
# Train Epoch 0 Progress: 34.67%	Loss: 2.1921
# Train Epoch 0 Progress: 35.2%	Loss: 2.0602
# Train Epoch 0 Progress: 35.73%	Loss: 2.1701
# Train Epoch 0 Progress: 36.27%	Loss: 2.1651
# Train Epoch 0 Progress: 36.8%	Loss: 2.1772
# Train Epoch 0 Progress: 37.33%	Loss: 2.1702
# Train Epoch 0 Progress: 37.87%	Loss: 2.1698
# Train Epoch 0 Progress: 38.4%	Loss: 2.0906
# Train Epoch 0 Progress: 38.93%	Loss: 2.1502
# Train Epoch 0 Progress: 39.47%	Loss: 2.0477
# Train Epoch 0 Progress: 40.0%	Loss: 2.1509
# Train Epoch 0 Progress: 40.53%	Loss: 2.076
# Train Epoch 0 Progress: 41.07%	Loss: 2.1349
# Train Epoch 0 Progress: 41.6%	Loss: 2.0683
# Train Epoch 0 Progress: 42.13%	Loss: 2.0349
# Train Epoch 0 Progress: 42.67%	Loss: 2.0511
# Train Epoch 0 Progress: 43.2%	Loss: 1.9336
# Train Epoch 0 Progress: 43.73%	Loss: 1.9252
# Train Epoch 0 Progress: 44.27%	Loss: 2.111
# Train Epoch 0 Progress: 44.8%	Loss: 1.9857
# Train Epoch 0 Progress: 45.33%	Loss: 1.9818
# Train Epoch 0 Progress: 45.87%	Loss: 2.0296
# Train Epoch 0 Progress: 46.4%	Loss: 2.0575
# Train Epoch 0 Progress: 46.93%	Loss: 1.9012
# Train Epoch 0 Progress: 47.47%	Loss: 1.9712
# Train Epoch 0 Progress: 48.0%	Loss: 2.0203
# Train Epoch 0 Progress: 48.53%	Loss: 1.9747
# Train Epoch 0 Progress: 49.07%	Loss: 2.0677
# Train Epoch 0 Progress: 49.6%	Loss: 1.8251
# Train Epoch 0 Progress: 50.13%	Loss: 1.9538
# Train Epoch 0 Progress: 50.67%	Loss: 1.8171
# Train Epoch 0 Progress: 51.2%	Loss: 1.8189
# Train Epoch 0 Progress: 51.73%	Loss: 2.0526
# Train Epoch 0 Progress: 52.27%	Loss: 1.9344
# Train Epoch 0 Progress: 52.8%	Loss: 1.865
# Train Epoch 0 Progress: 53.33%	Loss: 1.826
# Train Epoch 0 Progress: 53.87%	Loss: 1.8182
# Train Epoch 0 Progress: 54.4%	Loss: 1.5166
# Train Epoch 0 Progress: 54.93%	Loss: 1.8599
# Train Epoch 0 Progress: 55.47%	Loss: 1.7665
# Train Epoch 0 Progress: 56.0%	Loss: 1.9519
# Train Epoch 0 Progress: 56.53%	Loss: 1.8907
# Train Epoch 0 Progress: 57.07%	Loss: 1.8198
# Train Epoch 0 Progress: 57.6%	Loss: 1.7776
# Train Epoch 0 Progress: 58.13%	Loss: 1.912
# Train Epoch 0 Progress: 58.67%	Loss: 1.8865
# Train Epoch 0 Progress: 59.2%	Loss: 1.6526
# Train Epoch 0 Progress: 59.73%	Loss: 1.8083
# Train Epoch 0 Progress: 60.27%	Loss: 1.6519
# Train Epoch 0 Progress: 60.8%	Loss: 1.5819
# Train Epoch 0 Progress: 61.33%	Loss: 1.7839
# Train Epoch 0 Progress: 61.87%	Loss: 1.8836
# Train Epoch 0 Progress: 62.4%	Loss: 1.8735
# Train Epoch 0 Progress: 62.93%	Loss: 1.6367
# Train Epoch 0 Progress: 63.47%	Loss: 1.5264
# Train Epoch 0 Progress: 64.0%	Loss: 1.6014
# Train Epoch 0 Progress: 64.53%	Loss: 1.6021
# Train Epoch 0 Progress: 65.07%	Loss: 1.7016
# Train Epoch 0 Progress: 65.6%	Loss: 1.5347
# Train Epoch 0 Progress: 66.13%	Loss: 1.4029
# Train Epoch 0 Progress: 66.67%	Loss: 1.5486
# Train Epoch 0 Progress: 67.2%	Loss: 1.5502
# Train Epoch 0 Progress: 67.73%	Loss: 1.5135
# Train Epoch 0 Progress: 68.27%	Loss: 1.5708
# Train Epoch 0 Progress: 68.8%	Loss: 1.5252
# Train Epoch 0 Progress: 69.33%	Loss: 1.7141
# Train Epoch 0 Progress: 69.87%	Loss: 1.566
# Train Epoch 0 Progress: 70.4%	Loss: 1.4072
# Train Epoch 0 Progress: 70.93%	Loss: 1.5993
# Train Epoch 0 Progress: 71.47%	Loss: 1.307
# Train Epoch 0 Progress: 72.0%	Loss: 1.0721
# Train Epoch 0 Progress: 72.53%	Loss: 1.5934
# Train Epoch 0 Progress: 73.07%	Loss: 1.4307
# Train Epoch 0 Progress: 73.6%	Loss: 1.3089
# Train Epoch 0 Progress: 74.13%	Loss: 1.7248
# Train Epoch 0 Progress: 74.67%	Loss: 1.4981
# Train Epoch 0 Progress: 75.2%	Loss: 1.1869
# Train Epoch 0 Progress: 75.73%	Loss: 1.3323
# Train Epoch 0 Progress: 76.27%	Loss: 1.4894
# Train Epoch 0 Progress: 76.8%	Loss: 1.3817
# Train Epoch 0 Progress: 77.33%	Loss: 1.3387
# Train Epoch 0 Progress: 77.87%	Loss: 1.248
# Train Epoch 0 Progress: 78.4%	Loss: 1.1728
# Train Epoch 0 Progress: 78.93%	Loss: 1.3247
# Train Epoch 0 Progress: 79.47%	Loss: 1.3188
# Train Epoch 0 Progress: 80.0%	Loss: 1.3011
# Train Epoch 0 Progress: 80.53%	Loss: 1.3129
# Train Epoch 0 Progress: 81.07%	Loss: 1.367
# Train Epoch 0 Progress: 81.6%	Loss: 1.3849
# Train Epoch 0 Progress: 82.13%	Loss: 1.5575
# Train Epoch 0 Progress: 82.67%	Loss: 1.4065
# Train Epoch 0 Progress: 83.2%	Loss: 1.2615
# Train Epoch 0 Progress: 83.73%	Loss: 1.5
# Train Epoch 0 Progress: 84.27%	Loss: 1.3184
# Train Epoch 0 Progress: 84.8%	Loss: 1.3716
# Train Epoch 0 Progress: 85.33%	Loss: 1.3297
# Train Epoch 0 Progress: 85.87%	Loss: 1.3016
# Train Epoch 0 Progress: 86.4%	Loss: 1.4531
# Train Epoch 0 Progress: 86.93%	Loss: 1.0972
# Train Epoch 0 Progress: 87.47%	Loss: 1.2347
# Train Epoch 0 Progress: 88.0%	Loss: 1.3166
# Train Epoch 0 Progress: 88.53%	Loss: 1.4128
# Train Epoch 0 Progress: 89.07%	Loss: 1.613
# Train Epoch 0 Progress: 89.6%	Loss: 1.0699
# Train Epoch 0 Progress: 90.13%	Loss: 1.2419
# Train Epoch 0 Progress: 90.67%	Loss: 1.0505
# Train Epoch 0 Progress: 91.2%	Loss: 1.1394
# Train Epoch 0 Progress: 91.73%	Loss: 1.3034
# Train Epoch 0 Progress: 92.27%	Loss: 1.1327
# Train Epoch 0 Progress: 92.8%	Loss: 1.1686
# Train Epoch 0 Progress: 93.33%	Loss: 1.5173
# Train Epoch 0 Progress: 93.87%	Loss: 1.3642
# Train Epoch 0 Progress: 94.4%	Loss: 1.0084
# Train Epoch 0 Progress: 94.93%	Loss: 1.1286
# Train Epoch 0 Progress: 95.47%	Loss: 0.9649
# Train Epoch 0 Progress: 96.0%	Loss: 1.2698
# Train Epoch 0 Progress: 96.53%	Loss: 1.1583
# Train Epoch 0 Progress: 97.07%	Loss: 1.1944
# Train Epoch 0 Progress: 97.6%	Loss: 0.8904
# Train Epoch 0 Progress: 98.13%	Loss: 1.1099
# Train Epoch 0 Progress: 98.67%	Loss: 1.3249
# Train Epoch 0 Progress: 99.2%	Loss: 1.0733
# Train Epoch 0 Progress: 99.73%	Loss: 0.9868
#
# Test set: Avg loss 0.6845, Accuracy 84.5%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.8198
# Train Epoch 1 Progress: 0.53%	Loss: 1.2995
# Train Epoch 1 Progress: 1.07%	Loss: 1.0596
# Train Epoch 1 Progress: 1.6%	Loss: 1.509
# Train Epoch 1 Progress: 2.13%	Loss: 1.373
# Train Epoch 1 Progress: 2.67%	Loss: 1.3484
# Train Epoch 1 Progress: 3.2%	Loss: 0.8722
# Train Epoch 1 Progress: 3.73%	Loss: 0.9094
# Train Epoch 1 Progress: 4.27%	Loss: 1.052
# Train Epoch 1 Progress: 4.8%	Loss: 0.9304
# Train Epoch 1 Progress: 5.33%	Loss: 1.0912
# Train Epoch 1 Progress: 5.87%	Loss: 1.1688
# Train Epoch 1 Progress: 6.4%	Loss: 1.0485
# Train Epoch 1 Progress: 6.93%	Loss: 0.9254
# Train Epoch 1 Progress: 7.47%	Loss: 1.1447
# Train Epoch 1 Progress: 8.0%	Loss: 1.0582
# Train Epoch 1 Progress: 8.53%	Loss: 0.8793
# Train Epoch 1 Progress: 9.07%	Loss: 1.183
# Train Epoch 1 Progress: 9.6%	Loss: 1.2373
# Train Epoch 1 Progress: 10.13%	Loss: 0.7753
# Train Epoch 1 Progress: 10.67%	Loss: 1.0407
# Train Epoch 1 Progress: 11.2%	Loss: 0.8083
# Train Epoch 1 Progress: 11.73%	Loss: 0.8699
# Train Epoch 1 Progress: 12.27%	Loss: 1.0373
# Train Epoch 1 Progress: 12.8%	Loss: 1.1417
# Train Epoch 1 Progress: 13.33%	Loss: 0.9075
# Train Epoch 1 Progress: 13.87%	Loss: 1.1468
# Train Epoch 1 Progress: 14.4%	Loss: 1.0488
# Train Epoch 1 Progress: 14.93%	Loss: 0.7144
# Train Epoch 1 Progress: 15.47%	Loss: 0.9678
# Train Epoch 1 Progress: 16.0%	Loss: 1.1141
# Train Epoch 1 Progress: 16.53%	Loss: 1.2102
# Train Epoch 1 Progress: 17.07%	Loss: 0.876
# Train Epoch 1 Progress: 17.6%	Loss: 0.6775
# Train Epoch 1 Progress: 18.13%	Loss: 1.2135
# Train Epoch 1 Progress: 18.67%	Loss: 1.1761
# Train Epoch 1 Progress: 19.2%	Loss: 0.8361
# Train Epoch 1 Progress: 19.73%	Loss: 0.8294
# Train Epoch 1 Progress: 20.27%	Loss: 1.4139
# Train Epoch 1 Progress: 20.8%	Loss: 0.8292
# Train Epoch 1 Progress: 21.33%	Loss: 0.8543
# Train Epoch 1 Progress: 21.87%	Loss: 1.2677
# Train Epoch 1 Progress: 22.4%	Loss: 0.7868
# Train Epoch 1 Progress: 22.93%	Loss: 0.6346
# Train Epoch 1 Progress: 23.47%	Loss: 0.7415
# Train Epoch 1 Progress: 24.0%	Loss: 0.7308
# Train Epoch 1 Progress: 24.53%	Loss: 0.6415
# Train Epoch 1 Progress: 25.07%	Loss: 0.6959
# Train Epoch 1 Progress: 25.6%	Loss: 0.5368
# Train Epoch 1 Progress: 26.13%	Loss: 0.7933
# Train Epoch 1 Progress: 26.67%	Loss: 0.7748
# Train Epoch 1 Progress: 27.2%	Loss: 0.983
# Train Epoch 1 Progress: 27.73%	Loss: 0.8509
# Train Epoch 1 Progress: 28.27%	Loss: 1.0952
# Train Epoch 1 Progress: 28.8%	Loss: 0.783
# Train Epoch 1 Progress: 29.33%	Loss: 0.8381
# Train Epoch 1 Progress: 29.87%	Loss: 0.6366
# Train Epoch 1 Progress: 30.4%	Loss: 1.0111
# Train Epoch 1 Progress: 30.93%	Loss: 0.9574
# Train Epoch 1 Progress: 31.47%	Loss: 0.8646
# Train Epoch 1 Progress: 32.0%	Loss: 0.8719
# Train Epoch 1 Progress: 32.53%	Loss: 0.9959
# Train Epoch 1 Progress: 33.07%	Loss: 0.6997
# Train Epoch 1 Progress: 33.6%	Loss: 1.2312
# Train Epoch 1 Progress: 34.13%	Loss: 0.7977
# Train Epoch 1 Progress: 34.67%	Loss: 0.9276
# Train Epoch 1 Progress: 35.2%	Loss: 0.844
# Train Epoch 1 Progress: 35.73%	Loss: 0.6388
# Train Epoch 1 Progress: 36.27%	Loss: 0.8322
# Train Epoch 1 Progress: 36.8%	Loss: 0.9207
# Train Epoch 1 Progress: 37.33%	Loss: 0.6565
# Train Epoch 1 Progress: 37.87%	Loss: 0.7312
# Train Epoch 1 Progress: 38.4%	Loss: 0.5658
# Train Epoch 1 Progress: 38.93%	Loss: 0.9755
# Train Epoch 1 Progress: 39.47%	Loss: 1.0626
# Train Epoch 1 Progress: 40.0%	Loss: 0.585
# Train Epoch 1 Progress: 40.53%	Loss: 0.9883
# Train Epoch 1 Progress: 41.07%	Loss: 0.7453
# Train Epoch 1 Progress: 41.6%	Loss: 0.9714
# Train Epoch 1 Progress: 42.13%	Loss: 0.7546
# Train Epoch 1 Progress: 42.67%	Loss: 0.894
# Train Epoch 1 Progress: 43.2%	Loss: 1.0051
# Train Epoch 1 Progress: 43.73%	Loss: 0.7337
# Train Epoch 1 Progress: 44.27%	Loss: 0.992
# Train Epoch 1 Progress: 44.8%	Loss: 0.8396
# Train Epoch 1 Progress: 45.33%	Loss: 0.833
# Train Epoch 1 Progress: 45.87%	Loss: 0.8286
# Train Epoch 1 Progress: 46.4%	Loss: 0.6182
# Train Epoch 1 Progress: 46.93%	Loss: 0.8603
# Train Epoch 1 Progress: 47.47%	Loss: 0.9851
# Train Epoch 1 Progress: 48.0%	Loss: 0.6958
# Train Epoch 1 Progress: 48.53%	Loss: 0.8378
# Train Epoch 1 Progress: 49.07%	Loss: 0.8326
# Train Epoch 1 Progress: 49.6%	Loss: 1.0599
# Train Epoch 1 Progress: 50.13%	Loss: 0.7582
# Train Epoch 1 Progress: 50.67%	Loss: 0.8435
# Train Epoch 1 Progress: 51.2%	Loss: 0.6493
# Train Epoch 1 Progress: 51.73%	Loss: 0.8283
# Train Epoch 1 Progress: 52.27%	Loss: 0.8191
# Train Epoch 1 Progress: 52.8%	Loss: 0.822
# Train Epoch 1 Progress: 53.33%	Loss: 0.7079
# Train Epoch 1 Progress: 53.87%	Loss: 1.3163
# Train Epoch 1 Progress: 54.4%	Loss: 0.9691
# Train Epoch 1 Progress: 54.93%	Loss: 1.0924
# Train Epoch 1 Progress: 55.47%	Loss: 0.6383
# Train Epoch 1 Progress: 56.0%	Loss: 0.8952
# Train Epoch 1 Progress: 56.53%	Loss: 0.5693
# Train Epoch 1 Progress: 57.07%	Loss: 0.9306
# Train Epoch 1 Progress: 57.6%	Loss: 1.2208
# Train Epoch 1 Progress: 58.13%	Loss: 0.5195
# Train Epoch 1 Progress: 58.67%	Loss: 0.6215
# Train Epoch 1 Progress: 59.2%	Loss: 0.8712
# Train Epoch 1 Progress: 59.73%	Loss: 0.6076
# Train Epoch 1 Progress: 60.27%	Loss: 0.7305
# Train Epoch 1 Progress: 60.8%	Loss: 0.6612
# Train Epoch 1 Progress: 61.33%	Loss: 1.0227
# Train Epoch 1 Progress: 61.87%	Loss: 0.5521
# Train Epoch 1 Progress: 62.4%	Loss: 0.9695
# Train Epoch 1 Progress: 62.93%	Loss: 0.5585
# Train Epoch 1 Progress: 63.47%	Loss: 0.7033
# Train Epoch 1 Progress: 64.0%	Loss: 0.576
# Train Epoch 1 Progress: 64.53%	Loss: 0.6552
# Train Epoch 1 Progress: 65.07%	Loss: 0.7227
# Train Epoch 1 Progress: 65.6%	Loss: 0.6977
# Train Epoch 1 Progress: 66.13%	Loss: 0.8246
# Train Epoch 1 Progress: 66.67%	Loss: 0.3978
# Train Epoch 1 Progress: 67.2%	Loss: 0.8878
# Train Epoch 1 Progress: 67.73%	Loss: 0.5062
# Train Epoch 1 Progress: 68.27%	Loss: 0.913
# Train Epoch 1 Progress: 68.8%	Loss: 0.6391
# Train Epoch 1 Progress: 69.33%	Loss: 0.6109
# Train Epoch 1 Progress: 69.87%	Loss: 0.7889
# Train Epoch 1 Progress: 70.4%	Loss: 0.8366
# Train Epoch 1 Progress: 70.93%	Loss: 0.7041
# Train Epoch 1 Progress: 71.47%	Loss: 0.769
# Train Epoch 1 Progress: 72.0%	Loss: 0.8611
# Train Epoch 1 Progress: 72.53%	Loss: 0.5183
# Train Epoch 1 Progress: 73.07%	Loss: 0.5929
# Train Epoch 1 Progress: 73.6%	Loss: 0.6647
# Train Epoch 1 Progress: 74.13%	Loss: 0.8026
# Train Epoch 1 Progress: 74.67%	Loss: 1.0055
# Train Epoch 1 Progress: 75.2%	Loss: 0.7517
# Train Epoch 1 Progress: 75.73%	Loss: 1.0472
# Train Epoch 1 Progress: 76.27%	Loss: 0.6132
# Train Epoch 1 Progress: 76.8%	Loss: 1.0116
# Train Epoch 1 Progress: 77.33%	Loss: 0.5779
# Train Epoch 1 Progress: 77.87%	Loss: 0.8521
# Train Epoch 1 Progress: 78.4%	Loss: 0.5701
# Train Epoch 1 Progress: 78.93%	Loss: 0.7609
# Train Epoch 1 Progress: 79.47%	Loss: 0.3258
# Train Epoch 1 Progress: 80.0%	Loss: 0.9
# Train Epoch 1 Progress: 80.53%	Loss: 1.0777
# Train Epoch 1 Progress: 81.07%	Loss: 1.2419
# Train Epoch 1 Progress: 81.6%	Loss: 0.6551
# Train Epoch 1 Progress: 82.13%	Loss: 0.5861
# Train Epoch 1 Progress: 82.67%	Loss: 0.9464
# Train Epoch 1 Progress: 83.2%	Loss: 0.8841
# Train Epoch 1 Progress: 83.73%	Loss: 0.6361
# Train Epoch 1 Progress: 84.27%	Loss: 0.372
# Train Epoch 1 Progress: 84.8%	Loss: 0.8602
# Train Epoch 1 Progress: 85.33%	Loss: 0.8622
# Train Epoch 1 Progress: 85.87%	Loss: 0.8596
# Train Epoch 1 Progress: 86.4%	Loss: 0.7309
# Train Epoch 1 Progress: 86.93%	Loss: 0.477
# Train Epoch 1 Progress: 87.47%	Loss: 0.4742
# Train Epoch 1 Progress: 88.0%	Loss: 0.987
# Train Epoch 1 Progress: 88.53%	Loss: 0.9353
# Train Epoch 1 Progress: 89.07%	Loss: 0.9723
# Train Epoch 1 Progress: 89.6%	Loss: 0.5481
# Train Epoch 1 Progress: 90.13%	Loss: 0.6356
# Train Epoch 1 Progress: 90.67%	Loss: 0.6887
# Train Epoch 1 Progress: 91.2%	Loss: 0.8802
# Train Epoch 1 Progress: 91.73%	Loss: 0.587
# Train Epoch 1 Progress: 92.27%	Loss: 0.6723
# Train Epoch 1 Progress: 92.8%	Loss: 0.9122
# Train Epoch 1 Progress: 93.33%	Loss: 0.6458
# Train Epoch 1 Progress: 93.87%	Loss: 0.7425
# Train Epoch 1 Progress: 94.4%	Loss: 0.6972
# Train Epoch 1 Progress: 94.93%	Loss: 0.7546
# Train Epoch 1 Progress: 95.47%	Loss: 0.43
# Train Epoch 1 Progress: 96.0%	Loss: 0.5424
# Train Epoch 1 Progress: 96.53%	Loss: 0.5414
# Train Epoch 1 Progress: 97.07%	Loss: 0.7346
# Train Epoch 1 Progress: 97.6%	Loss: 0.6616
# Train Epoch 1 Progress: 98.13%	Loss: 0.6057
# Train Epoch 1 Progress: 98.67%	Loss: 0.5293
# Train Epoch 1 Progress: 99.2%	Loss: 0.5865
# Train Epoch 1 Progress: 99.73%	Loss: 0.4822
#
# Test set: Avg loss 0.3285, Accuracy 91.48%
#
# Training with lr=0.001, momentum=0.5, batch_size=64
#
# Test set: Avg loss 2.3145, Accuracy 9.75%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.2991
# Train Epoch 0 Progress: 1.07%	Loss: 2.3143
# Train Epoch 0 Progress: 2.13%	Loss: 2.2983
# Train Epoch 0 Progress: 3.2%	Loss: 2.3347
# Train Epoch 0 Progress: 4.27%	Loss: 2.3178
# Train Epoch 0 Progress: 5.33%	Loss: 2.3233
# Train Epoch 0 Progress: 6.4%	Loss: 2.2905
# Train Epoch 0 Progress: 7.47%	Loss: 2.3136
# Train Epoch 0 Progress: 8.53%	Loss: 2.298
# Train Epoch 0 Progress: 9.6%	Loss: 2.3278
# Train Epoch 0 Progress: 10.67%	Loss: 2.2645
# Train Epoch 0 Progress: 11.73%	Loss: 2.2967
# Train Epoch 0 Progress: 12.8%	Loss: 2.3134
# Train Epoch 0 Progress: 13.87%	Loss: 2.3179
# Train Epoch 0 Progress: 14.93%	Loss: 2.2762
# Train Epoch 0 Progress: 16.0%	Loss: 2.2969
# Train Epoch 0 Progress: 17.07%	Loss: 2.3175
# Train Epoch 0 Progress: 18.13%	Loss: 2.2964
# Train Epoch 0 Progress: 19.2%	Loss: 2.3072
# Train Epoch 0 Progress: 20.27%	Loss: 2.3152
# Train Epoch 0 Progress: 21.33%	Loss: 2.2961
# Train Epoch 0 Progress: 22.4%	Loss: 2.2689
# Train Epoch 0 Progress: 23.47%	Loss: 2.293
# Train Epoch 0 Progress: 24.53%	Loss: 2.3103
# Train Epoch 0 Progress: 25.6%	Loss: 2.2733
# Train Epoch 0 Progress: 26.67%	Loss: 2.2699
# Train Epoch 0 Progress: 27.73%	Loss: 2.2951
# Train Epoch 0 Progress: 28.8%	Loss: 2.2942
# Train Epoch 0 Progress: 29.87%	Loss: 2.3074
# Train Epoch 0 Progress: 30.93%	Loss: 2.2802
# Train Epoch 0 Progress: 32.0%	Loss: 2.281
# Train Epoch 0 Progress: 33.07%	Loss: 2.2763
# Train Epoch 0 Progress: 34.13%	Loss: 2.2881
# Train Epoch 0 Progress: 35.2%	Loss: 2.2606
# Train Epoch 0 Progress: 36.27%	Loss: 2.2732
# Train Epoch 0 Progress: 37.33%	Loss: 2.2921
# Train Epoch 0 Progress: 38.4%	Loss: 2.2645
# Train Epoch 0 Progress: 39.47%	Loss: 2.282
# Train Epoch 0 Progress: 40.53%	Loss: 2.2616
# Train Epoch 0 Progress: 41.6%	Loss: 2.2734
# Train Epoch 0 Progress: 42.67%	Loss: 2.2732
# Train Epoch 0 Progress: 43.73%	Loss: 2.2499
# Train Epoch 0 Progress: 44.8%	Loss: 2.2554
# Train Epoch 0 Progress: 45.87%	Loss: 2.2754
# Train Epoch 0 Progress: 46.93%	Loss: 2.2782
# Train Epoch 0 Progress: 48.0%	Loss: 2.2766
# Train Epoch 0 Progress: 49.07%	Loss: 2.2509
# Train Epoch 0 Progress: 50.13%	Loss: 2.2496
# Train Epoch 0 Progress: 51.2%	Loss: 2.283
# Train Epoch 0 Progress: 52.27%	Loss: 2.2523
# Train Epoch 0 Progress: 53.33%	Loss: 2.2313
# Train Epoch 0 Progress: 54.4%	Loss: 2.2409
# Train Epoch 0 Progress: 55.47%	Loss: 2.2594
# Train Epoch 0 Progress: 56.53%	Loss: 2.2404
# Train Epoch 0 Progress: 57.6%	Loss: 2.2453
# Train Epoch 0 Progress: 58.67%	Loss: 2.2697
# Train Epoch 0 Progress: 59.73%	Loss: 2.301
# Train Epoch 0 Progress: 60.8%	Loss: 2.2054
# Train Epoch 0 Progress: 61.87%	Loss: 2.2732
# Train Epoch 0 Progress: 62.93%	Loss: 2.2233
# Train Epoch 0 Progress: 64.0%	Loss: 2.2583
# Train Epoch 0 Progress: 65.07%	Loss: 2.2496
# Train Epoch 0 Progress: 66.13%	Loss: 2.2362
# Train Epoch 0 Progress: 67.2%	Loss: 2.2223
# Train Epoch 0 Progress: 68.27%	Loss: 2.2347
# Train Epoch 0 Progress: 69.33%	Loss: 2.2321
# Train Epoch 0 Progress: 70.4%	Loss: 2.2066
# Train Epoch 0 Progress: 71.47%	Loss: 2.2387
# Train Epoch 0 Progress: 72.53%	Loss: 2.2293
# Train Epoch 0 Progress: 73.6%	Loss: 2.2565
# Train Epoch 0 Progress: 74.67%	Loss: 2.2261
# Train Epoch 0 Progress: 75.73%	Loss: 2.2088
# Train Epoch 0 Progress: 76.8%	Loss: 2.178
# Train Epoch 0 Progress: 77.87%	Loss: 2.2177
# Train Epoch 0 Progress: 78.93%	Loss: 2.1891
# Train Epoch 0 Progress: 80.0%	Loss: 2.199
# Train Epoch 0 Progress: 81.07%	Loss: 2.2332
# Train Epoch 0 Progress: 82.13%	Loss: 2.2186
# Train Epoch 0 Progress: 83.2%	Loss: 2.2325
# Train Epoch 0 Progress: 84.27%	Loss: 2.1607
# Train Epoch 0 Progress: 85.33%	Loss: 2.1978
# Train Epoch 0 Progress: 86.4%	Loss: 2.159
# Train Epoch 0 Progress: 87.47%	Loss: 2.2093
# Train Epoch 0 Progress: 88.53%	Loss: 2.2058
# Train Epoch 0 Progress: 89.6%	Loss: 2.1759
# Train Epoch 0 Progress: 90.67%	Loss: 2.169
# Train Epoch 0 Progress: 91.73%	Loss: 2.2232
# Train Epoch 0 Progress: 92.8%	Loss: 2.18
# Train Epoch 0 Progress: 93.87%	Loss: 2.142
# Train Epoch 0 Progress: 94.93%	Loss: 2.1592
# Train Epoch 0 Progress: 96.0%	Loss: 2.1675
# Train Epoch 0 Progress: 97.07%	Loss: 2.1838
# Train Epoch 0 Progress: 98.13%	Loss: 2.1415
# Train Epoch 0 Progress: 99.2%	Loss: 2.1461
#
# Test set: Avg loss 2.0713, Accuracy 58.48%
#
# Train Epoch 1 Progress: 0.0%	Loss: 2.108
# Train Epoch 1 Progress: 1.07%	Loss: 2.0325
# Train Epoch 1 Progress: 2.13%	Loss: 2.017
# Train Epoch 1 Progress: 3.2%	Loss: 2.1233
# Train Epoch 1 Progress: 4.27%	Loss: 2.1044
# Train Epoch 1 Progress: 5.33%	Loss: 2.1752
# Train Epoch 1 Progress: 6.4%	Loss: 2.078
# Train Epoch 1 Progress: 7.47%	Loss: 2.0585
# Train Epoch 1 Progress: 8.53%	Loss: 2.0914
# Train Epoch 1 Progress: 9.6%	Loss: 2.1012
# Train Epoch 1 Progress: 10.67%	Loss: 2.145
# Train Epoch 1 Progress: 11.73%	Loss: 2.004
# Train Epoch 1 Progress: 12.8%	Loss: 2.0236
# Train Epoch 1 Progress: 13.87%	Loss: 2.0683
# Train Epoch 1 Progress: 14.93%	Loss: 2.1214
# Train Epoch 1 Progress: 16.0%	Loss: 1.9923
# Train Epoch 1 Progress: 17.07%	Loss: 2.0602
# Train Epoch 1 Progress: 18.13%	Loss: 2.0235
# Train Epoch 1 Progress: 19.2%	Loss: 1.9091
# Train Epoch 1 Progress: 20.27%	Loss: 2.0482
# Train Epoch 1 Progress: 21.33%	Loss: 2.027
# Train Epoch 1 Progress: 22.4%	Loss: 1.9255
# Train Epoch 1 Progress: 23.47%	Loss: 2.0242
# Train Epoch 1 Progress: 24.53%	Loss: 1.898
# Train Epoch 1 Progress: 25.6%	Loss: 1.9237
# Train Epoch 1 Progress: 26.67%	Loss: 1.8933
# Train Epoch 1 Progress: 27.73%	Loss: 1.8935
# Train Epoch 1 Progress: 28.8%	Loss: 1.7622
# Train Epoch 1 Progress: 29.87%	Loss: 1.8992
# Train Epoch 1 Progress: 30.93%	Loss: 1.8253
# Train Epoch 1 Progress: 32.0%	Loss: 1.9247
# Train Epoch 1 Progress: 33.07%	Loss: 1.7806
# Train Epoch 1 Progress: 34.13%	Loss: 1.875
# Train Epoch 1 Progress: 35.2%	Loss: 1.8725
# Train Epoch 1 Progress: 36.27%	Loss: 1.6537
# Train Epoch 1 Progress: 37.33%	Loss: 1.7269
# Train Epoch 1 Progress: 38.4%	Loss: 1.9979
# Train Epoch 1 Progress: 39.47%	Loss: 1.7832
# Train Epoch 1 Progress: 40.53%	Loss: 1.7232
# Train Epoch 1 Progress: 41.6%	Loss: 1.9406
# Train Epoch 1 Progress: 42.67%	Loss: 1.7738
# Train Epoch 1 Progress: 43.73%	Loss: 1.8826
# Train Epoch 1 Progress: 44.8%	Loss: 1.7284
# Train Epoch 1 Progress: 45.87%	Loss: 1.7548
# Train Epoch 1 Progress: 46.93%	Loss: 1.6515
# Train Epoch 1 Progress: 48.0%	Loss: 1.5909
# Train Epoch 1 Progress: 49.07%	Loss: 1.7283
# Train Epoch 1 Progress: 50.13%	Loss: 1.6075
# Train Epoch 1 Progress: 51.2%	Loss: 1.4885
# Train Epoch 1 Progress: 52.27%	Loss: 1.3857
# Train Epoch 1 Progress: 53.33%	Loss: 1.5507
# Train Epoch 1 Progress: 54.4%	Loss: 1.6651
# Train Epoch 1 Progress: 55.47%	Loss: 1.6043
# Train Epoch 1 Progress: 56.53%	Loss: 1.6214
# Train Epoch 1 Progress: 57.6%	Loss: 1.5042
# Train Epoch 1 Progress: 58.67%	Loss: 1.4564
# Train Epoch 1 Progress: 59.73%	Loss: 1.551
# Train Epoch 1 Progress: 60.8%	Loss: 1.5103
# Train Epoch 1 Progress: 61.87%	Loss: 1.6195
# Train Epoch 1 Progress: 62.93%	Loss: 1.4143
# Train Epoch 1 Progress: 64.0%	Loss: 1.3805
# Train Epoch 1 Progress: 65.07%	Loss: 1.4727
# Train Epoch 1 Progress: 66.13%	Loss: 1.3972
# Train Epoch 1 Progress: 67.2%	Loss: 1.3243
# Train Epoch 1 Progress: 68.27%	Loss: 1.4371
# Train Epoch 1 Progress: 69.33%	Loss: 1.4317
# Train Epoch 1 Progress: 70.4%	Loss: 1.4279
# Train Epoch 1 Progress: 71.47%	Loss: 1.5456
# Train Epoch 1 Progress: 72.53%	Loss: 1.3443
# Train Epoch 1 Progress: 73.6%	Loss: 1.3403
# Train Epoch 1 Progress: 74.67%	Loss: 1.3582
# Train Epoch 1 Progress: 75.73%	Loss: 1.3461
# Train Epoch 1 Progress: 76.8%	Loss: 1.3952
# Train Epoch 1 Progress: 77.87%	Loss: 1.3434
# Train Epoch 1 Progress: 78.93%	Loss: 1.3304
# Train Epoch 1 Progress: 80.0%	Loss: 1.6183
# Train Epoch 1 Progress: 81.07%	Loss: 1.4425
# Train Epoch 1 Progress: 82.13%	Loss: 1.3424
# Train Epoch 1 Progress: 83.2%	Loss: 1.3573
# Train Epoch 1 Progress: 84.27%	Loss: 1.3217
# Train Epoch 1 Progress: 85.33%	Loss: 1.2818
# Train Epoch 1 Progress: 86.4%	Loss: 1.2937
# Train Epoch 1 Progress: 87.47%	Loss: 1.3682
# Train Epoch 1 Progress: 88.53%	Loss: 1.235
# Train Epoch 1 Progress: 89.6%	Loss: 1.3471
# Train Epoch 1 Progress: 90.67%	Loss: 0.9517
# Train Epoch 1 Progress: 91.73%	Loss: 1.4777
# Train Epoch 1 Progress: 92.8%	Loss: 1.4363
# Train Epoch 1 Progress: 93.87%	Loss: 1.1441
# Train Epoch 1 Progress: 94.93%	Loss: 1.2969
# Train Epoch 1 Progress: 96.0%	Loss: 1.2933
# Train Epoch 1 Progress: 97.07%	Loss: 1.3575
# Train Epoch 1 Progress: 98.13%	Loss: 1.6825
# Train Epoch 1 Progress: 99.2%	Loss: 1.2649
#
# Test set: Avg loss 0.8108, Accuracy 83.14%
#
# Training with lr=0.001, momentum=0.5, batch_size=128
#
# Test set: Avg loss 2.3123, Accuracy 9.66%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3072
# Train Epoch 0 Progress: 2.13%	Loss: 2.3134
# Train Epoch 0 Progress: 4.27%	Loss: 2.2808
# Train Epoch 0 Progress: 6.4%	Loss: 2.3104
# Train Epoch 0 Progress: 8.53%	Loss: 2.3101
# Train Epoch 0 Progress: 10.67%	Loss: 2.3144
# Train Epoch 0 Progress: 12.8%	Loss: 2.3391
# Train Epoch 0 Progress: 14.93%	Loss: 2.3139
# Train Epoch 0 Progress: 17.07%	Loss: 2.3151
# Train Epoch 0 Progress: 19.2%	Loss: 2.2798
# Train Epoch 0 Progress: 21.33%	Loss: 2.2937
# Train Epoch 0 Progress: 23.47%	Loss: 2.306
# Train Epoch 0 Progress: 25.6%	Loss: 2.2737
# Train Epoch 0 Progress: 27.73%	Loss: 2.2922
# Train Epoch 0 Progress: 29.87%	Loss: 2.2665
# Train Epoch 0 Progress: 32.0%	Loss: 2.2947
# Train Epoch 0 Progress: 34.13%	Loss: 2.2669
# Train Epoch 0 Progress: 36.27%	Loss: 2.3106
# Train Epoch 0 Progress: 38.4%	Loss: 2.29
# Train Epoch 0 Progress: 40.53%	Loss: 2.2635
# Train Epoch 0 Progress: 42.67%	Loss: 2.2702
# Train Epoch 0 Progress: 44.8%	Loss: 2.2669
# Train Epoch 0 Progress: 46.93%	Loss: 2.2888
# Train Epoch 0 Progress: 49.07%	Loss: 2.2826
# Train Epoch 0 Progress: 51.2%	Loss: 2.2739
# Train Epoch 0 Progress: 53.33%	Loss: 2.2939
# Train Epoch 0 Progress: 55.47%	Loss: 2.2881
# Train Epoch 0 Progress: 57.6%	Loss: 2.2932
# Train Epoch 0 Progress: 59.73%	Loss: 2.2688
# Train Epoch 0 Progress: 61.87%	Loss: 2.2741
# Train Epoch 0 Progress: 64.0%	Loss: 2.2749
# Train Epoch 0 Progress: 66.13%	Loss: 2.2895
# Train Epoch 0 Progress: 68.27%	Loss: 2.3026
# Train Epoch 0 Progress: 70.4%	Loss: 2.2897
# Train Epoch 0 Progress: 72.53%	Loss: 2.2803
# Train Epoch 0 Progress: 74.67%	Loss: 2.2592
# Train Epoch 0 Progress: 76.8%	Loss: 2.263
# Train Epoch 0 Progress: 78.93%	Loss: 2.2499
# Train Epoch 0 Progress: 81.07%	Loss: 2.2601
# Train Epoch 0 Progress: 83.2%	Loss: 2.2526
# Train Epoch 0 Progress: 85.33%	Loss: 2.2684
# Train Epoch 0 Progress: 87.47%	Loss: 2.2683
# Train Epoch 0 Progress: 89.6%	Loss: 2.2816
# Train Epoch 0 Progress: 91.73%	Loss: 2.2914
# Train Epoch 0 Progress: 93.87%	Loss: 2.2551
# Train Epoch 0 Progress: 96.0%	Loss: 2.2494
# Train Epoch 0 Progress: 98.13%	Loss: 2.2825
#
# Test set: Avg loss 2.2365, Accuracy 26.89%
#
# Train Epoch 1 Progress: 0.0%	Loss: 2.2494
# Train Epoch 1 Progress: 2.13%	Loss: 2.2625
# Train Epoch 1 Progress: 4.27%	Loss: 2.2498
# Train Epoch 1 Progress: 6.4%	Loss: 2.2511
# Train Epoch 1 Progress: 8.53%	Loss: 2.2308
# Train Epoch 1 Progress: 10.67%	Loss: 2.2631
# Train Epoch 1 Progress: 12.8%	Loss: 2.2439
# Train Epoch 1 Progress: 14.93%	Loss: 2.2554
# Train Epoch 1 Progress: 17.07%	Loss: 2.2611
# Train Epoch 1 Progress: 19.2%	Loss: 2.2663
# Train Epoch 1 Progress: 21.33%	Loss: 2.2259
# Train Epoch 1 Progress: 23.47%	Loss: 2.2467
# Train Epoch 1 Progress: 25.6%	Loss: 2.2356
# Train Epoch 1 Progress: 27.73%	Loss: 2.1714
# Train Epoch 1 Progress: 29.87%	Loss: 2.2574
# Train Epoch 1 Progress: 32.0%	Loss: 2.1959
# Train Epoch 1 Progress: 34.13%	Loss: 2.2478
# Train Epoch 1 Progress: 36.27%	Loss: 2.2033
# Train Epoch 1 Progress: 38.4%	Loss: 2.2129
# Train Epoch 1 Progress: 40.53%	Loss: 2.2079
# Train Epoch 1 Progress: 42.67%	Loss: 2.2005
# Train Epoch 1 Progress: 44.8%	Loss: 2.2398
# Train Epoch 1 Progress: 46.93%	Loss: 2.1862
# Train Epoch 1 Progress: 49.07%	Loss: 2.1946
# Train Epoch 1 Progress: 51.2%	Loss: 2.2031
# Train Epoch 1 Progress: 53.33%	Loss: 2.2418
# Train Epoch 1 Progress: 55.47%	Loss: 2.2152
# Train Epoch 1 Progress: 57.6%	Loss: 2.2033
# Train Epoch 1 Progress: 59.73%	Loss: 2.1453
# Train Epoch 1 Progress: 61.87%	Loss: 2.1777
# Train Epoch 1 Progress: 64.0%	Loss: 2.1617
# Train Epoch 1 Progress: 66.13%	Loss: 2.1564
# Train Epoch 1 Progress: 68.27%	Loss: 2.1399
# Train Epoch 1 Progress: 70.4%	Loss: 2.1473
# Train Epoch 1 Progress: 72.53%	Loss: 2.1173
# Train Epoch 1 Progress: 74.67%	Loss: 2.1203
# Train Epoch 1 Progress: 76.8%	Loss: 2.1533
# Train Epoch 1 Progress: 78.93%	Loss: 2.1104
# Train Epoch 1 Progress: 81.07%	Loss: 2.1637
# Train Epoch 1 Progress: 83.2%	Loss: 2.1671
# Train Epoch 1 Progress: 85.33%	Loss: 2.1387
# Train Epoch 1 Progress: 87.47%	Loss: 2.0948
# Train Epoch 1 Progress: 89.6%	Loss: 2.1185
# Train Epoch 1 Progress: 91.73%	Loss: 2.1108
# Train Epoch 1 Progress: 93.87%	Loss: 2.1203
# Train Epoch 1 Progress: 96.0%	Loss: 2.1033
# Train Epoch 1 Progress: 98.13%	Loss: 2.0896
#
# Test set: Avg loss 1.9905, Accuracy 61.79%
#
# Training with lr=0.001, momentum=0.9, batch_size=32
#
# Test set: Avg loss 2.3086, Accuracy 9.15%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3179
# Train Epoch 0 Progress: 0.53%	Loss: 2.2477
# Train Epoch 0 Progress: 1.07%	Loss: 2.3341
# Train Epoch 0 Progress: 1.6%	Loss: 2.2887
# Train Epoch 0 Progress: 2.13%	Loss: 2.3195
# Train Epoch 0 Progress: 2.67%	Loss: 2.2645
# Train Epoch 0 Progress: 3.2%	Loss: 2.2655
# Train Epoch 0 Progress: 3.73%	Loss: 2.2537
# Train Epoch 0 Progress: 4.27%	Loss: 2.205
# Train Epoch 0 Progress: 4.8%	Loss: 2.2222
# Train Epoch 0 Progress: 5.33%	Loss: 2.127
# Train Epoch 0 Progress: 5.87%	Loss: 2.2351
# Train Epoch 0 Progress: 6.4%	Loss: 2.2186
# Train Epoch 0 Progress: 6.93%	Loss: 2.1494
# Train Epoch 0 Progress: 7.47%	Loss: 2.1219
# Train Epoch 0 Progress: 8.0%	Loss: 2.197
# Train Epoch 0 Progress: 8.53%	Loss: 2.2073
# Train Epoch 0 Progress: 9.07%	Loss: 1.982
# Train Epoch 0 Progress: 9.6%	Loss: 2.0128
# Train Epoch 0 Progress: 10.13%	Loss: 2.1168
# Train Epoch 0 Progress: 10.67%	Loss: 1.9916
# Train Epoch 0 Progress: 11.2%	Loss: 1.902
# Train Epoch 0 Progress: 11.73%	Loss: 1.8537
# Train Epoch 0 Progress: 12.27%	Loss: 1.5528
# Train Epoch 0 Progress: 12.8%	Loss: 1.6958
# Train Epoch 0 Progress: 13.33%	Loss: 1.4153
# Train Epoch 0 Progress: 13.87%	Loss: 1.4791
# Train Epoch 0 Progress: 14.4%	Loss: 1.598
# Train Epoch 0 Progress: 14.93%	Loss: 1.6291
# Train Epoch 0 Progress: 15.47%	Loss: 1.379
# Train Epoch 0 Progress: 16.0%	Loss: 1.4202
# Train Epoch 0 Progress: 16.53%	Loss: 1.6342
# Train Epoch 0 Progress: 17.07%	Loss: 1.3197
# Train Epoch 0 Progress: 17.6%	Loss: 1.4514
# Train Epoch 0 Progress: 18.13%	Loss: 0.8315
# Train Epoch 0 Progress: 18.67%	Loss: 1.4542
# Train Epoch 0 Progress: 19.2%	Loss: 1.1949
# Train Epoch 0 Progress: 19.73%	Loss: 0.9574
# Train Epoch 0 Progress: 20.27%	Loss: 1.0373
# Train Epoch 0 Progress: 20.8%	Loss: 1.0786
# Train Epoch 0 Progress: 21.33%	Loss: 1.4171
# Train Epoch 0 Progress: 21.87%	Loss: 1.2476
# Train Epoch 0 Progress: 22.4%	Loss: 0.821
# Train Epoch 0 Progress: 22.93%	Loss: 0.6495
# Train Epoch 0 Progress: 23.47%	Loss: 1.1632
# Train Epoch 0 Progress: 24.0%	Loss: 1.1618
# Train Epoch 0 Progress: 24.53%	Loss: 1.5263
# Train Epoch 0 Progress: 25.07%	Loss: 1.0277
# Train Epoch 0 Progress: 25.6%	Loss: 1.2852
# Train Epoch 0 Progress: 26.13%	Loss: 0.7313
# Train Epoch 0 Progress: 26.67%	Loss: 0.7055
# Train Epoch 0 Progress: 27.2%	Loss: 0.7179
# Train Epoch 0 Progress: 27.73%	Loss: 1.0284
# Train Epoch 0 Progress: 28.27%	Loss: 0.8547
# Train Epoch 0 Progress: 28.8%	Loss: 0.9378
# Train Epoch 0 Progress: 29.33%	Loss: 0.8049
# Train Epoch 0 Progress: 29.87%	Loss: 0.819
# Train Epoch 0 Progress: 30.4%	Loss: 0.5851
# Train Epoch 0 Progress: 30.93%	Loss: 0.9084
# Train Epoch 0 Progress: 31.47%	Loss: 0.7592
# Train Epoch 0 Progress: 32.0%	Loss: 0.6721
# Train Epoch 0 Progress: 32.53%	Loss: 0.6798
# Train Epoch 0 Progress: 33.07%	Loss: 0.5687
# Train Epoch 0 Progress: 33.6%	Loss: 0.8322
# Train Epoch 0 Progress: 34.13%	Loss: 0.5513
# Train Epoch 0 Progress: 34.67%	Loss: 0.6676
# Train Epoch 0 Progress: 35.2%	Loss: 1.1822
# Train Epoch 0 Progress: 35.73%	Loss: 0.8067
# Train Epoch 0 Progress: 36.27%	Loss: 0.6257
# Train Epoch 0 Progress: 36.8%	Loss: 0.7887
# Train Epoch 0 Progress: 37.33%	Loss: 0.674
# Train Epoch 0 Progress: 37.87%	Loss: 0.9047
# Train Epoch 0 Progress: 38.4%	Loss: 1.0951
# Train Epoch 0 Progress: 38.93%	Loss: 0.5656
# Train Epoch 0 Progress: 39.47%	Loss: 0.7248
# Train Epoch 0 Progress: 40.0%	Loss: 0.6392
# Train Epoch 0 Progress: 40.53%	Loss: 0.7018
# Train Epoch 0 Progress: 41.07%	Loss: 0.9212
# Train Epoch 0 Progress: 41.6%	Loss: 1.233
# Train Epoch 0 Progress: 42.13%	Loss: 0.7798
# Train Epoch 0 Progress: 42.67%	Loss: 0.549
# Train Epoch 0 Progress: 43.2%	Loss: 0.7314
# Train Epoch 0 Progress: 43.73%	Loss: 0.7065
# Train Epoch 0 Progress: 44.27%	Loss: 0.4521
# Train Epoch 0 Progress: 44.8%	Loss: 0.6743
# Train Epoch 0 Progress: 45.33%	Loss: 0.6167
# Train Epoch 0 Progress: 45.87%	Loss: 0.453
# Train Epoch 0 Progress: 46.4%	Loss: 0.5162
# Train Epoch 0 Progress: 46.93%	Loss: 0.5785
# Train Epoch 0 Progress: 47.47%	Loss: 0.6705
# Train Epoch 0 Progress: 48.0%	Loss: 1.4305
# Train Epoch 0 Progress: 48.53%	Loss: 0.664
# Train Epoch 0 Progress: 49.07%	Loss: 0.974
# Train Epoch 0 Progress: 49.6%	Loss: 0.6998
# Train Epoch 0 Progress: 50.13%	Loss: 0.3666
# Train Epoch 0 Progress: 50.67%	Loss: 0.6692
# Train Epoch 0 Progress: 51.2%	Loss: 0.6344
# Train Epoch 0 Progress: 51.73%	Loss: 0.3965
# Train Epoch 0 Progress: 52.27%	Loss: 0.5253
# Train Epoch 0 Progress: 52.8%	Loss: 0.601
# Train Epoch 0 Progress: 53.33%	Loss: 0.3827
# Train Epoch 0 Progress: 53.87%	Loss: 0.6236
# Train Epoch 0 Progress: 54.4%	Loss: 0.9308
# Train Epoch 0 Progress: 54.93%	Loss: 0.6177
# Train Epoch 0 Progress: 55.47%	Loss: 0.5668
# Train Epoch 0 Progress: 56.0%	Loss: 0.4792
# Train Epoch 0 Progress: 56.53%	Loss: 0.7742
# Train Epoch 0 Progress: 57.07%	Loss: 0.5839
# Train Epoch 0 Progress: 57.6%	Loss: 0.5568
# Train Epoch 0 Progress: 58.13%	Loss: 0.4477
# Train Epoch 0 Progress: 58.67%	Loss: 0.3054
# Train Epoch 0 Progress: 59.2%	Loss: 0.4708
# Train Epoch 0 Progress: 59.73%	Loss: 1.0146
# Train Epoch 0 Progress: 60.27%	Loss: 0.5467
# Train Epoch 0 Progress: 60.8%	Loss: 0.697
# Train Epoch 0 Progress: 61.33%	Loss: 1.1217
# Train Epoch 0 Progress: 61.87%	Loss: 0.3909
# Train Epoch 0 Progress: 62.4%	Loss: 0.6288
# Train Epoch 0 Progress: 62.93%	Loss: 0.7532
# Train Epoch 0 Progress: 63.47%	Loss: 0.6229
# Train Epoch 0 Progress: 64.0%	Loss: 0.5246
# Train Epoch 0 Progress: 64.53%	Loss: 0.4979
# Train Epoch 0 Progress: 65.07%	Loss: 0.5052
# Train Epoch 0 Progress: 65.6%	Loss: 0.5291
# Train Epoch 0 Progress: 66.13%	Loss: 0.6344
# Train Epoch 0 Progress: 66.67%	Loss: 0.4317
# Train Epoch 0 Progress: 67.2%	Loss: 0.6032
# Train Epoch 0 Progress: 67.73%	Loss: 0.6832
# Train Epoch 0 Progress: 68.27%	Loss: 0.4522
# Train Epoch 0 Progress: 68.8%	Loss: 0.9903
# Train Epoch 0 Progress: 69.33%	Loss: 0.4728
# Train Epoch 0 Progress: 69.87%	Loss: 0.2952
# Train Epoch 0 Progress: 70.4%	Loss: 0.5276
# Train Epoch 0 Progress: 70.93%	Loss: 0.6463
# Train Epoch 0 Progress: 71.47%	Loss: 0.4624
# Train Epoch 0 Progress: 72.0%	Loss: 0.4687
# Train Epoch 0 Progress: 72.53%	Loss: 0.2976
# Train Epoch 0 Progress: 73.07%	Loss: 0.977
# Train Epoch 0 Progress: 73.6%	Loss: 0.8302
# Train Epoch 0 Progress: 74.13%	Loss: 0.4262
# Train Epoch 0 Progress: 74.67%	Loss: 0.37
# Train Epoch 0 Progress: 75.2%	Loss: 0.6643
# Train Epoch 0 Progress: 75.73%	Loss: 0.5572
# Train Epoch 0 Progress: 76.27%	Loss: 0.3852
# Train Epoch 0 Progress: 76.8%	Loss: 0.4521
# Train Epoch 0 Progress: 77.33%	Loss: 0.6075
# Train Epoch 0 Progress: 77.87%	Loss: 0.6067
# Train Epoch 0 Progress: 78.4%	Loss: 0.567
# Train Epoch 0 Progress: 78.93%	Loss: 0.2846
# Train Epoch 0 Progress: 79.47%	Loss: 0.462
# Train Epoch 0 Progress: 80.0%	Loss: 0.2229
# Train Epoch 0 Progress: 80.53%	Loss: 0.2615
# Train Epoch 0 Progress: 81.07%	Loss: 0.5465
# Train Epoch 0 Progress: 81.6%	Loss: 0.4838
# Train Epoch 0 Progress: 82.13%	Loss: 0.3431
# Train Epoch 0 Progress: 82.67%	Loss: 0.2529
# Train Epoch 0 Progress: 83.2%	Loss: 0.3265
# Train Epoch 0 Progress: 83.73%	Loss: 0.2396
# Train Epoch 0 Progress: 84.27%	Loss: 0.3174
# Train Epoch 0 Progress: 84.8%	Loss: 0.939
# Train Epoch 0 Progress: 85.33%	Loss: 0.1628
# Train Epoch 0 Progress: 85.87%	Loss: 0.5715
# Train Epoch 0 Progress: 86.4%	Loss: 0.3837
# Train Epoch 0 Progress: 86.93%	Loss: 0.4794
# Train Epoch 0 Progress: 87.47%	Loss: 0.6143
# Train Epoch 0 Progress: 88.0%	Loss: 0.4623
# Train Epoch 0 Progress: 88.53%	Loss: 0.559
# Train Epoch 0 Progress: 89.07%	Loss: 0.4348
# Train Epoch 0 Progress: 89.6%	Loss: 0.4703
# Train Epoch 0 Progress: 90.13%	Loss: 0.4195
# Train Epoch 0 Progress: 90.67%	Loss: 0.9622
# Train Epoch 0 Progress: 91.2%	Loss: 0.6179
# Train Epoch 0 Progress: 91.73%	Loss: 0.6166
# Train Epoch 0 Progress: 92.27%	Loss: 0.2073
# Train Epoch 0 Progress: 92.8%	Loss: 0.5436
# Train Epoch 0 Progress: 93.33%	Loss: 0.6224
# Train Epoch 0 Progress: 93.87%	Loss: 0.4786
# Train Epoch 0 Progress: 94.4%	Loss: 0.433
# Train Epoch 0 Progress: 94.93%	Loss: 0.3348
# Train Epoch 0 Progress: 95.47%	Loss: 0.2782
# Train Epoch 0 Progress: 96.0%	Loss: 0.4867
# Train Epoch 0 Progress: 96.53%	Loss: 0.3285
# Train Epoch 0 Progress: 97.07%	Loss: 0.316
# Train Epoch 0 Progress: 97.6%	Loss: 0.2776
# Train Epoch 0 Progress: 98.13%	Loss: 0.6346
# Train Epoch 0 Progress: 98.67%	Loss: 0.4308
# Train Epoch 0 Progress: 99.2%	Loss: 0.4317
# Train Epoch 0 Progress: 99.73%	Loss: 0.5301
#
# Test set: Avg loss 0.1772, Accuracy 94.84%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.4083
# Train Epoch 1 Progress: 0.53%	Loss: 0.4681
# Train Epoch 1 Progress: 1.07%	Loss: 0.3453
# Train Epoch 1 Progress: 1.6%	Loss: 0.4668
# Train Epoch 1 Progress: 2.13%	Loss: 0.4299
# Train Epoch 1 Progress: 2.67%	Loss: 0.483
# Train Epoch 1 Progress: 3.2%	Loss: 0.3942
# Train Epoch 1 Progress: 3.73%	Loss: 0.461
# Train Epoch 1 Progress: 4.27%	Loss: 0.4716
# Train Epoch 1 Progress: 4.8%	Loss: 0.2836
# Train Epoch 1 Progress: 5.33%	Loss: 0.368
# Train Epoch 1 Progress: 5.87%	Loss: 0.4171
# Train Epoch 1 Progress: 6.4%	Loss: 0.2718
# Train Epoch 1 Progress: 6.93%	Loss: 0.4973
# Train Epoch 1 Progress: 7.47%	Loss: 0.3488
# Train Epoch 1 Progress: 8.0%	Loss: 0.1589
# Train Epoch 1 Progress: 8.53%	Loss: 0.367
# Train Epoch 1 Progress: 9.07%	Loss: 0.2597
# Train Epoch 1 Progress: 9.6%	Loss: 0.7219
# Train Epoch 1 Progress: 10.13%	Loss: 0.6173
# Train Epoch 1 Progress: 10.67%	Loss: 0.2421
# Train Epoch 1 Progress: 11.2%	Loss: 0.2239
# Train Epoch 1 Progress: 11.73%	Loss: 0.1799
# Train Epoch 1 Progress: 12.27%	Loss: 0.3415
# Train Epoch 1 Progress: 12.8%	Loss: 0.2604
# Train Epoch 1 Progress: 13.33%	Loss: 0.1242
# Train Epoch 1 Progress: 13.87%	Loss: 0.3609
# Train Epoch 1 Progress: 14.4%	Loss: 0.7121
# Train Epoch 1 Progress: 14.93%	Loss: 0.6982
# Train Epoch 1 Progress: 15.47%	Loss: 0.4258
# Train Epoch 1 Progress: 16.0%	Loss: 0.703
# Train Epoch 1 Progress: 16.53%	Loss: 0.3791
# Train Epoch 1 Progress: 17.07%	Loss: 0.5768
# Train Epoch 1 Progress: 17.6%	Loss: 0.5922
# Train Epoch 1 Progress: 18.13%	Loss: 0.4486
# Train Epoch 1 Progress: 18.67%	Loss: 0.4253
# Train Epoch 1 Progress: 19.2%	Loss: 0.2386
# Train Epoch 1 Progress: 19.73%	Loss: 0.5062
# Train Epoch 1 Progress: 20.27%	Loss: 0.2658
# Train Epoch 1 Progress: 20.8%	Loss: 0.6619
# Train Epoch 1 Progress: 21.33%	Loss: 0.2836
# Train Epoch 1 Progress: 21.87%	Loss: 0.2381
# Train Epoch 1 Progress: 22.4%	Loss: 0.2779
# Train Epoch 1 Progress: 22.93%	Loss: 0.3301
# Train Epoch 1 Progress: 23.47%	Loss: 0.2521
# Train Epoch 1 Progress: 24.0%	Loss: 0.6799
# Train Epoch 1 Progress: 24.53%	Loss: 0.2192
# Train Epoch 1 Progress: 25.07%	Loss: 0.4648
# Train Epoch 1 Progress: 25.6%	Loss: 0.2671
# Train Epoch 1 Progress: 26.13%	Loss: 0.3032
# Train Epoch 1 Progress: 26.67%	Loss: 0.2501
# Train Epoch 1 Progress: 27.2%	Loss: 0.4767
# Train Epoch 1 Progress: 27.73%	Loss: 0.3239
# Train Epoch 1 Progress: 28.27%	Loss: 0.2399
# Train Epoch 1 Progress: 28.8%	Loss: 0.4547
# Train Epoch 1 Progress: 29.33%	Loss: 0.3727
# Train Epoch 1 Progress: 29.87%	Loss: 0.4739
# Train Epoch 1 Progress: 30.4%	Loss: 0.3794
# Train Epoch 1 Progress: 30.93%	Loss: 0.4023
# Train Epoch 1 Progress: 31.47%	Loss: 0.531
# Train Epoch 1 Progress: 32.0%	Loss: 0.5377
# Train Epoch 1 Progress: 32.53%	Loss: 0.1955
# Train Epoch 1 Progress: 33.07%	Loss: 0.4508
# Train Epoch 1 Progress: 33.6%	Loss: 0.1534
# Train Epoch 1 Progress: 34.13%	Loss: 0.3538
# Train Epoch 1 Progress: 34.67%	Loss: 0.1544
# Train Epoch 1 Progress: 35.2%	Loss: 0.4457
# Train Epoch 1 Progress: 35.73%	Loss: 0.3665
# Train Epoch 1 Progress: 36.27%	Loss: 0.3493
# Train Epoch 1 Progress: 36.8%	Loss: 0.338
# Train Epoch 1 Progress: 37.33%	Loss: 0.2159
# Train Epoch 1 Progress: 37.87%	Loss: 0.5275
# Train Epoch 1 Progress: 38.4%	Loss: 0.1218
# Train Epoch 1 Progress: 38.93%	Loss: 0.0907
# Train Epoch 1 Progress: 39.47%	Loss: 0.8214
# Train Epoch 1 Progress: 40.0%	Loss: 0.4218
# Train Epoch 1 Progress: 40.53%	Loss: 0.5101
# Train Epoch 1 Progress: 41.07%	Loss: 0.1407
# Train Epoch 1 Progress: 41.6%	Loss: 0.2663
# Train Epoch 1 Progress: 42.13%	Loss: 0.7699
# Train Epoch 1 Progress: 42.67%	Loss: 0.2117
# Train Epoch 1 Progress: 43.2%	Loss: 0.2247
# Train Epoch 1 Progress: 43.73%	Loss: 0.3291
# Train Epoch 1 Progress: 44.27%	Loss: 0.4529
# Train Epoch 1 Progress: 44.8%	Loss: 0.1996
# Train Epoch 1 Progress: 45.33%	Loss: 0.403
# Train Epoch 1 Progress: 45.87%	Loss: 0.6917
# Train Epoch 1 Progress: 46.4%	Loss: 0.4442
# Train Epoch 1 Progress: 46.93%	Loss: 0.3702
# Train Epoch 1 Progress: 47.47%	Loss: 0.1265
# Train Epoch 1 Progress: 48.0%	Loss: 0.3557
# Train Epoch 1 Progress: 48.53%	Loss: 0.2621
# Train Epoch 1 Progress: 49.07%	Loss: 0.2439
# Train Epoch 1 Progress: 49.6%	Loss: 0.2859
# Train Epoch 1 Progress: 50.13%	Loss: 0.1991
# Train Epoch 1 Progress: 50.67%	Loss: 0.3806
# Train Epoch 1 Progress: 51.2%	Loss: 0.3469
# Train Epoch 1 Progress: 51.73%	Loss: 0.8219
# Train Epoch 1 Progress: 52.27%	Loss: 0.6061
# Train Epoch 1 Progress: 52.8%	Loss: 0.5597
# Train Epoch 1 Progress: 53.33%	Loss: 0.2602
# Train Epoch 1 Progress: 53.87%	Loss: 0.3976
# Train Epoch 1 Progress: 54.4%	Loss: 0.5963
# Train Epoch 1 Progress: 54.93%	Loss: 0.3189
# Train Epoch 1 Progress: 55.47%	Loss: 0.4629
# Train Epoch 1 Progress: 56.0%	Loss: 0.1965
# Train Epoch 1 Progress: 56.53%	Loss: 0.3216
# Train Epoch 1 Progress: 57.07%	Loss: 0.2615
# Train Epoch 1 Progress: 57.6%	Loss: 0.2547
# Train Epoch 1 Progress: 58.13%	Loss: 0.2442
# Train Epoch 1 Progress: 58.67%	Loss: 0.3697
# Train Epoch 1 Progress: 59.2%	Loss: 0.2583
# Train Epoch 1 Progress: 59.73%	Loss: 0.656
# Train Epoch 1 Progress: 60.27%	Loss: 0.6646
# Train Epoch 1 Progress: 60.8%	Loss: 0.7249
# Train Epoch 1 Progress: 61.33%	Loss: 0.4932
# Train Epoch 1 Progress: 61.87%	Loss: 0.1163
# Train Epoch 1 Progress: 62.4%	Loss: 0.6263
# Train Epoch 1 Progress: 62.93%	Loss: 0.364
# Train Epoch 1 Progress: 63.47%	Loss: 0.4086
# Train Epoch 1 Progress: 64.0%	Loss: 0.3301
# Train Epoch 1 Progress: 64.53%	Loss: 0.2231
# Train Epoch 1 Progress: 65.07%	Loss: 0.3297
# Train Epoch 1 Progress: 65.6%	Loss: 0.3071
# Train Epoch 1 Progress: 66.13%	Loss: 0.3752
# Train Epoch 1 Progress: 66.67%	Loss: 0.5233
# Train Epoch 1 Progress: 67.2%	Loss: 0.3026
# Train Epoch 1 Progress: 67.73%	Loss: 0.4325
# Train Epoch 1 Progress: 68.27%	Loss: 0.1735
# Train Epoch 1 Progress: 68.8%	Loss: 0.4293
# Train Epoch 1 Progress: 69.33%	Loss: 0.2079
# Train Epoch 1 Progress: 69.87%	Loss: 0.2277
# Train Epoch 1 Progress: 70.4%	Loss: 0.2952
# Train Epoch 1 Progress: 70.93%	Loss: 0.4189
# Train Epoch 1 Progress: 71.47%	Loss: 0.1095
# Train Epoch 1 Progress: 72.0%	Loss: 0.1406
# Train Epoch 1 Progress: 72.53%	Loss: 0.3499
# Train Epoch 1 Progress: 73.07%	Loss: 0.3642
# Train Epoch 1 Progress: 73.6%	Loss: 0.2169
# Train Epoch 1 Progress: 74.13%	Loss: 0.1949
# Train Epoch 1 Progress: 74.67%	Loss: 0.2935
# Train Epoch 1 Progress: 75.2%	Loss: 0.3074
# Train Epoch 1 Progress: 75.73%	Loss: 0.1213
# Train Epoch 1 Progress: 76.27%	Loss: 0.1401
# Train Epoch 1 Progress: 76.8%	Loss: 0.1951
# Train Epoch 1 Progress: 77.33%	Loss: 0.4505
# Train Epoch 1 Progress: 77.87%	Loss: 0.5039
# Train Epoch 1 Progress: 78.4%	Loss: 0.1673
# Train Epoch 1 Progress: 78.93%	Loss: 0.3439
# Train Epoch 1 Progress: 79.47%	Loss: 0.5505
# Train Epoch 1 Progress: 80.0%	Loss: 0.2917
# Train Epoch 1 Progress: 80.53%	Loss: 0.1697
# Train Epoch 1 Progress: 81.07%	Loss: 0.4222
# Train Epoch 1 Progress: 81.6%	Loss: 0.3537
# Train Epoch 1 Progress: 82.13%	Loss: 0.6117
# Train Epoch 1 Progress: 82.67%	Loss: 0.8025
# Train Epoch 1 Progress: 83.2%	Loss: 0.2712
# Train Epoch 1 Progress: 83.73%	Loss: 0.1716
# Train Epoch 1 Progress: 84.27%	Loss: 0.4803
# Train Epoch 1 Progress: 84.8%	Loss: 0.4201
# Train Epoch 1 Progress: 85.33%	Loss: 0.3037
# Train Epoch 1 Progress: 85.87%	Loss: 0.3642
# Train Epoch 1 Progress: 86.4%	Loss: 0.4943
# Train Epoch 1 Progress: 86.93%	Loss: 0.229
# Train Epoch 1 Progress: 87.47%	Loss: 0.2177
# Train Epoch 1 Progress: 88.0%	Loss: 0.221
# Train Epoch 1 Progress: 88.53%	Loss: 0.2486
# Train Epoch 1 Progress: 89.07%	Loss: 0.2847
# Train Epoch 1 Progress: 89.6%	Loss: 0.1761
# Train Epoch 1 Progress: 90.13%	Loss: 0.4537
# Train Epoch 1 Progress: 90.67%	Loss: 0.1132
# Train Epoch 1 Progress: 91.2%	Loss: 0.5884
# Train Epoch 1 Progress: 91.73%	Loss: 0.2735
# Train Epoch 1 Progress: 92.27%	Loss: 0.2327
# Train Epoch 1 Progress: 92.8%	Loss: 0.5668
# Train Epoch 1 Progress: 93.33%	Loss: 0.2842
# Train Epoch 1 Progress: 93.87%	Loss: 0.2424
# Train Epoch 1 Progress: 94.4%	Loss: 0.3405
# Train Epoch 1 Progress: 94.93%	Loss: 0.3328
# Train Epoch 1 Progress: 95.47%	Loss: 0.5247
# Train Epoch 1 Progress: 96.0%	Loss: 0.5722
# Train Epoch 1 Progress: 96.53%	Loss: 0.429
# Train Epoch 1 Progress: 97.07%	Loss: 0.1545
# Train Epoch 1 Progress: 97.6%	Loss: 0.8182
# Train Epoch 1 Progress: 98.13%	Loss: 0.1883
# Train Epoch 1 Progress: 98.67%	Loss: 0.2115
# Train Epoch 1 Progress: 99.2%	Loss: 0.2917
# Train Epoch 1 Progress: 99.73%	Loss: 0.2726
#
# Test set: Avg loss 0.1157, Accuracy 96.5%
#
# Training with lr=0.001, momentum=0.9, batch_size=64
#
# Test set: Avg loss 2.298, Accuracy 19.91%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.347
# Train Epoch 0 Progress: 1.07%	Loss: 2.3219
# Train Epoch 0 Progress: 2.13%	Loss: 2.2938
# Train Epoch 0 Progress: 3.2%	Loss: 2.2874
# Train Epoch 0 Progress: 4.27%	Loss: 2.299
# Train Epoch 0 Progress: 5.33%	Loss: 2.2872
# Train Epoch 0 Progress: 6.4%	Loss: 2.2602
# Train Epoch 0 Progress: 7.47%	Loss: 2.2811
# Train Epoch 0 Progress: 8.53%	Loss: 2.2241
# Train Epoch 0 Progress: 9.6%	Loss: 2.2405
# Train Epoch 0 Progress: 10.67%	Loss: 2.2199
# Train Epoch 0 Progress: 11.73%	Loss: 2.2315
# Train Epoch 0 Progress: 12.8%	Loss: 2.207
# Train Epoch 0 Progress: 13.87%	Loss: 2.1687
# Train Epoch 0 Progress: 14.93%	Loss: 2.0516
# Train Epoch 0 Progress: 16.0%	Loss: 2.1175
# Train Epoch 0 Progress: 17.07%	Loss: 2.1095
# Train Epoch 0 Progress: 18.13%	Loss: 1.9488
# Train Epoch 0 Progress: 19.2%	Loss: 2.1193
# Train Epoch 0 Progress: 20.27%	Loss: 1.9295
# Train Epoch 0 Progress: 21.33%	Loss: 1.9417
# Train Epoch 0 Progress: 22.4%	Loss: 1.799
# Train Epoch 0 Progress: 23.47%	Loss: 1.8315
# Train Epoch 0 Progress: 24.53%	Loss: 1.7747
# Train Epoch 0 Progress: 25.6%	Loss: 1.8688
# Train Epoch 0 Progress: 26.67%	Loss: 1.8397
# Train Epoch 0 Progress: 27.73%	Loss: 1.6442
# Train Epoch 0 Progress: 28.8%	Loss: 1.6932
# Train Epoch 0 Progress: 29.87%	Loss: 1.4806
# Train Epoch 0 Progress: 30.93%	Loss: 1.3372
# Train Epoch 0 Progress: 32.0%	Loss: 1.4964
# Train Epoch 0 Progress: 33.07%	Loss: 1.4641
# Train Epoch 0 Progress: 34.13%	Loss: 1.3397
# Train Epoch 0 Progress: 35.2%	Loss: 1.1651
# Train Epoch 0 Progress: 36.27%	Loss: 1.2253
# Train Epoch 0 Progress: 37.33%	Loss: 1.3432
# Train Epoch 0 Progress: 38.4%	Loss: 1.0869
# Train Epoch 0 Progress: 39.47%	Loss: 1.337
# Train Epoch 0 Progress: 40.53%	Loss: 1.2742
# Train Epoch 0 Progress: 41.6%	Loss: 1.318
# Train Epoch 0 Progress: 42.67%	Loss: 1.1403
# Train Epoch 0 Progress: 43.73%	Loss: 1.3137
# Train Epoch 0 Progress: 44.8%	Loss: 0.8569
# Train Epoch 0 Progress: 45.87%	Loss: 0.9503
# Train Epoch 0 Progress: 46.93%	Loss: 1.2121
# Train Epoch 0 Progress: 48.0%	Loss: 1.1036
# Train Epoch 0 Progress: 49.07%	Loss: 1.1279
# Train Epoch 0 Progress: 50.13%	Loss: 1.0307
# Train Epoch 0 Progress: 51.2%	Loss: 1.0153
# Train Epoch 0 Progress: 52.27%	Loss: 1.003
# Train Epoch 0 Progress: 53.33%	Loss: 0.8706
# ...
# Train Epoch 1 Progress: 75.2%	Loss: 0.4264
# Train Epoch 1 Progress: 75.73%	Loss: 0.3465
# Train Epoch 1 Progress: 76.27%	Loss: 0.3072
# Train Epoch 1 Progress: 76.8%	Loss: 0.207
# Train Epoch 1 Progress: 77.33%	Loss: 0.2487
# Train Epoch 1 Progress: 77.87%	Loss: 0.6025
# Train Epoch 1 Progress: 78.4%	Loss: 0.267
# Train Epoch 1 Progress: 78.93%	Loss: 0.2181
# Train Epoch 1 Progress: 79.47%	Loss: 0.1211
# Train Epoch 1 Progress: 80.0%	Loss: 0.9617
# Train Epoch 1 Progress: 80.53%	Loss: 0.5714
# Train Epoch 1 Progress: 81.07%	Loss: 0.3193
# Train Epoch 1 Progress: 81.6%	Loss: 0.6639
# Train Epoch 1 Progress: 82.13%	Loss: 0.3523
# Train Epoch 1 Progress: 82.67%	Loss: 0.2114
# Train Epoch 1 Progress: 83.2%	Loss: 0.5068
# Train Epoch 1 Progress: 83.73%	Loss: 0.3243
# Train Epoch 1 Progress: 84.27%	Loss: 0.1331
# Train Epoch 1 Progress: 84.8%	Loss: 0.2412
# Train Epoch 1 Progress: 85.33%	Loss: 0.2791
# Train Epoch 1 Progress: 85.87%	Loss: 0.0797
# Train Epoch 1 Progress: 86.4%	Loss: 0.1408
# Train Epoch 1 Progress: 86.93%	Loss: 0.1515
# Train Epoch 1 Progress: 87.47%	Loss: 0.2139
# Train Epoch 1 Progress: 88.0%	Loss: 0.3134
# Train Epoch 1 Progress: 88.53%	Loss: 0.0412
# Train Epoch 1 Progress: 89.07%	Loss: 0.5226
# Train Epoch 1 Progress: 89.6%	Loss: 0.3839
# Train Epoch 1 Progress: 90.13%	Loss: 0.285
# Train Epoch 1 Progress: 90.67%	Loss: 0.2361
# Train Epoch 1 Progress: 91.2%	Loss: 0.1823
# Train Epoch 1 Progress: 91.73%	Loss: 0.4652
# Train Epoch 1 Progress: 92.27%	Loss: 0.2224
# Train Epoch 1 Progress: 92.8%	Loss: 0.3221
# Train Epoch 1 Progress: 93.33%	Loss: 0.3974
# Train Epoch 1 Progress: 93.87%	Loss: 0.4318
# Train Epoch 1 Progress: 94.4%	Loss: 0.3079
# Train Epoch 1 Progress: 94.93%	Loss: 0.2106
# Train Epoch 1 Progress: 95.47%	Loss: 0.1961
# Train Epoch 1 Progress: 96.0%	Loss: 0.1832
# Train Epoch 1 Progress: 96.53%	Loss: 0.1684
# Train Epoch 1 Progress: 97.07%	Loss: 0.1324
# Train Epoch 1 Progress: 97.6%	Loss: 0.2974
# Train Epoch 1 Progress: 98.13%	Loss: 0.1567
# Train Epoch 1 Progress: 98.67%	Loss: 0.263
# Train Epoch 1 Progress: 99.2%	Loss: 0.2063
# Train Epoch 1 Progress: 99.73%	Loss: 0.4033
#
# Test set: Avg loss 0.0911, Accuracy 97.12%
#
# Training with lr=0.01, momentum=0.5, batch_size=64
#
# Test set: Avg loss 2.3111, Accuracy 9.41%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3129
# Train Epoch 0 Progress: 1.07%	Loss: 2.286
# Train Epoch 0 Progress: 2.13%	Loss: 2.2846
# Train Epoch 0 Progress: 3.2%	Loss: 2.2509
# Train Epoch 0 Progress: 4.27%	Loss: 2.2792
# Train Epoch 0 Progress: 5.33%	Loss: 2.28
# Train Epoch 0 Progress: 6.4%	Loss: 2.2229
# Train Epoch 0 Progress: 7.47%	Loss: 2.1974
# Train Epoch 0 Progress: 8.53%	Loss: 2.1827
# Train Epoch 0 Progress: 9.6%	Loss: 2.1125
# Train Epoch 0 Progress: 10.67%	Loss: 2.1323
# Train Epoch 0 Progress: 11.73%	Loss: 2.0864
# Train Epoch 0 Progress: 12.8%	Loss: 1.8705
# Train Epoch 0 Progress: 13.87%	Loss: 1.8727
# Train Epoch 0 Progress: 14.93%	Loss: 1.7052
# Train Epoch 0 Progress: 16.0%	Loss: 1.713
# Train Epoch 0 Progress: 17.07%	Loss: 1.775
# Train Epoch 0 Progress: 18.13%	Loss: 1.4199
# Train Epoch 0 Progress: 19.2%	Loss: 1.6193
# Train Epoch 0 Progress: 20.27%	Loss: 1.3316
# Train Epoch 0 Progress: 21.33%	Loss: 1.3557
# Train Epoch 0 Progress: 22.4%	Loss: 1.1841
# Train Epoch 0 Progress: 23.47%	Loss: 1.0765
# Train Epoch 0 Progress: 24.53%	Loss: 1.0667
# Train Epoch 0 Progress: 25.6%	Loss: 1.0082
# Train Epoch 0 Progress: 26.67%	Loss: 1.0733
# Train Epoch 0 Progress: 27.73%	Loss: 0.9382
# Train Epoch 0 Progress: 28.8%	Loss: 0.8985
# Train Epoch 0 Progress: 29.87%	Loss: 0.5782
# Train Epoch 0 Progress: 30.93%	Loss: 0.7814
# Train Epoch 0 Progress: 32.0%	Loss: 0.9336
# Train Epoch 0 Progress: 33.07%	Loss: 0.6867
# Train Epoch 0 Progress: 34.13%	Loss: 0.7767
# Train Epoch 0 Progress: 35.2%	Loss: 0.7983
# Train Epoch 0 Progress: 36.27%	Loss: 0.6154
# Train Epoch 0 Progress: 37.33%	Loss: 0.8695
# Train Epoch 0 Progress: 38.4%	Loss: 1.0877
# Train Epoch 0 Progress: 39.47%	Loss: 0.7902
# Train Epoch 0 Progress: 40.53%	Loss: 0.7107
# Train Epoch 0 Progress: 41.6%	Loss: 0.7325
# Train Epoch 0 Progress: 42.67%	Loss: 0.6694
# Train Epoch 0 Progress: 43.73%	Loss: 0.7168
# Train Epoch 0 Progress: 44.8%	Loss: 0.8932
# Train Epoch 0 Progress: 45.87%	Loss: 0.5654
# Train Epoch 0 Progress: 46.93%	Loss: 0.5233
# Train Epoch 0 Progress: 48.0%	Loss: 0.7289
# Train Epoch 0 Progress: 49.07%	Loss: 0.5808
# Train Epoch 0 Progress: 50.13%	Loss: 0.5724
# Train Epoch 0 Progress: 51.2%	Loss: 0.7271
# Train Epoch 0 Progress: 52.27%	Loss: 0.5251
# Train Epoch 0 Progress: 53.33%	Loss: 0.5305
# Train Epoch 0 Progress: 54.4%	Loss: 0.5738
# Train Epoch 0 Progress: 55.47%	Loss: 0.6413
# Train Epoch 0 Progress: 56.53%	Loss: 0.5824
# Train Epoch 0 Progress: 57.6%	Loss: 0.4802
# Train Epoch 0 Progress: 58.67%	Loss: 0.5246
# Train Epoch 0 Progress: 59.73%	Loss: 0.7316
# Train Epoch 0 Progress: 60.8%	Loss: 0.5563
# Train Epoch 0 Progress: 61.87%	Loss: 0.7891
# Train Epoch 0 Progress: 62.93%	Loss: 0.5755
# Train Epoch 0 Progress: 64.0%	Loss: 0.5997
# Train Epoch 0 Progress: 65.07%	Loss: 0.4672
# Train Epoch 0 Progress: 66.13%	Loss: 0.577
# Train Epoch 0 Progress: 67.2%	Loss: 0.5132
# Train Epoch 0 Progress: 68.27%	Loss: 0.3012
# Train Epoch 0 Progress: 69.33%	Loss: 0.481
# Train Epoch 0 Progress: 70.4%	Loss: 0.7536
# Train Epoch 0 Progress: 71.47%	Loss: 0.3445
# Train Epoch 0 Progress: 72.53%	Loss: 0.5838
# Train Epoch 0 Progress: 73.6%	Loss: 0.4825
# Train Epoch 0 Progress: 74.67%	Loss: 0.522
# Train Epoch 0 Progress: 75.73%	Loss: 0.595
# Train Epoch 0 Progress: 76.8%	Loss: 0.4432
# Train Epoch 0 Progress: 77.87%	Loss: 0.5559
# Train Epoch 0 Progress: 78.93%	Loss: 0.5404
# Train Epoch 0 Progress: 80.0%	Loss: 0.6587
# Train Epoch 0 Progress: 81.07%	Loss: 0.4198
# Train Epoch 0 Progress: 82.13%	Loss: 0.3519
# Train Epoch 0 Progress: 83.2%	Loss: 0.4765
# Train Epoch 0 Progress: 84.27%	Loss: 0.3943
# Train Epoch 0 Progress: 85.33%	Loss: 0.3161
# Train Epoch 0 Progress: 86.4%	Loss: 0.3632
# Train Epoch 0 Progress: 87.47%	Loss: 0.3868
# Train Epoch 0 Progress: 88.53%	Loss: 0.2139
# Train Epoch 0 Progress: 89.6%	Loss: 0.5486
# Train Epoch 0 Progress: 90.67%	Loss: 0.411
# Train Epoch 0 Progress: 91.73%	Loss: 0.2847
# Train Epoch 0 Progress: 92.8%	Loss: 0.4481
# Train Epoch 0 Progress: 93.87%	Loss: 0.8714
# Train Epoch 0 Progress: 94.93%	Loss: 0.4349
# Train Epoch 0 Progress: 96.0%	Loss: 0.3019
# Train Epoch 0 Progress: 97.07%	Loss: 0.2953
# Train Epoch 0 Progress: 98.13%	Loss: 0.3932
# Train Epoch 0 Progress: 99.2%	Loss: 0.4063
#
# Test set: Avg loss 0.1665, Accuracy 94.98%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.3538
# Train Epoch 1 Progress: 1.07%	Loss: 0.395
# Train Epoch 1 Progress: 2.13%	Loss: 0.4781
# Train Epoch 1 Progress: 3.2%	Loss: 0.5477
# Train Epoch 1 Progress: 4.27%	Loss: 0.3585
# Train Epoch 1 Progress: 5.33%	Loss: 0.5769
# Train Epoch 1 Progress: 6.4%	Loss: 0.3565
# Train Epoch 1 Progress: 7.47%	Loss: 0.1988
# Train Epoch 1 Progress: 8.53%	Loss: 0.5077
# Train Epoch 1 Progress: 9.6%	Loss: 0.1691
# Train Epoch 1 Progress: 10.67%	Loss: 0.3837
# Train Epoch 1 Progress: 11.73%	Loss: 0.6149
# Train Epoch 1 Progress: 12.8%	Loss: 0.4023
# Train Epoch 1 Progress: 13.87%	Loss: 0.3839
# Train Epoch 1 Progress: 14.93%	Loss: 0.3775
# Train Epoch 1 Progress: 16.0%	Loss: 0.2766
# Train Epoch 1 Progress: 17.07%	Loss: 0.3523
# Train Epoch 1 Progress: 18.13%	Loss: 0.4037
# Train Epoch 1 Progress: 19.2%	Loss: 0.1765
# Train Epoch 1 Progress: 20.27%	Loss: 0.4509
# Train Epoch 1 Progress: 21.33%	Loss: 0.3332
# Train Epoch 1 Progress: 22.4%	Loss: 0.2823
# Train Epoch 1 Progress: 23.47%	Loss: 0.2568
# Train Epoch 1 Progress: 24.53%	Loss: 0.4186
# Train Epoch 1 Progress: 25.6%	Loss: 0.4444
# Train Epoch 1 Progress: 26.67%	Loss: 0.2178
# Train Epoch 1 Progress: 27.73%	Loss: 0.4087
# Train Epoch 1 Progress: 28.8%	Loss: 0.4471
# Train Epoch 1 Progress: 29.87%	Loss: 0.4253
# Train Epoch 1 Progress: 30.93%	Loss: 0.3227
# Train Epoch 1 Progress: 32.0%	Loss: 0.3389
# Train Epoch 1 Progress: 33.07%	Loss: 0.304
# Train Epoch 1 Progress: 34.13%	Loss: 0.4922
# Train Epoch 1 Progress: 35.2%	Loss: 0.3716
# Train Epoch 1 Progress: 36.27%	Loss: 0.3423
# Train Epoch 1 Progress: 37.33%	Loss: 0.2309
# Train Epoch 1 Progress: 38.4%	Loss: 0.4661
# Train Epoch 1 Progress: 39.47%	Loss: 0.2742
# Train Epoch 1 Progress: 40.53%	Loss: 0.4754
# Train Epoch 1 Progress: 41.6%	Loss: 0.4204
# Train Epoch 1 Progress: 42.67%	Loss: 0.3304
# Train Epoch 1 Progress: 43.73%	Loss: 0.307
# Train Epoch 1 Progress: 44.8%	Loss: 0.2167
# Train Epoch 1 Progress: 45.87%	Loss: 0.1982
# Train Epoch 1 Progress: 46.93%	Loss: 0.6402
# Train Epoch 1 Progress: 48.0%	Loss: 0.3832
# Train Epoch 1 Progress: 49.07%	Loss: 0.1643
# Train Epoch 1 Progress: 50.13%	Loss: 0.3236
# Train Epoch 1 Progress: 51.2%	Loss: 0.2738
# Train Epoch 1 Progress: 52.27%	Loss: 0.318
# Train Epoch 1 Progress: 53.33%	Loss: 0.3312
# Train Epoch 1 Progress: 54.4%	Loss: 0.4291
# Train Epoch 1 Progress: 55.47%	Loss: 0.1602
# Train Epoch 1 Progress: 56.53%	Loss: 0.3527
# Train Epoch 1 Progress: 57.6%	Loss: 0.2945
# Train Epoch 1 Progress: 58.67%	Loss: 0.4763
# Train Epoch 1 Progress: 59.73%	Loss: 0.1866
# Train Epoch 1 Progress: 60.8%	Loss: 0.236
# Train Epoch 1 Progress: 61.87%	Loss: 0.2559
# Train Epoch 1 Progress: 62.93%	Loss: 0.3686
# Train Epoch 1 Progress: 64.0%	Loss: 0.3671
# Train Epoch 1 Progress: 65.07%	Loss: 0.5193
# Train Epoch 1 Progress: 66.13%	Loss: 0.6795
# Train Epoch 1 Progress: 67.2%	Loss: 0.0911
# Train Epoch 1 Progress: 68.27%	Loss: 0.3732
# Train Epoch 1 Progress: 69.33%	Loss: 0.2966
# Train Epoch 1 Progress: 70.4%	Loss: 0.2858
# Train Epoch 1 Progress: 71.47%	Loss: 0.3411
# Train Epoch 1 Progress: 72.53%	Loss: 0.3404
# Train Epoch 1 Progress: 73.6%	Loss: 0.3478
# Train Epoch 1 Progress: 74.67%	Loss: 0.1563
# Train Epoch 1 Progress: 75.73%	Loss: 0.3844
# Train Epoch 1 Progress: 76.8%	Loss: 0.1791
# Train Epoch 1 Progress: 77.87%	Loss: 0.2369
# Train Epoch 1 Progress: 78.93%	Loss: 0.326
# Train Epoch 1 Progress: 80.0%	Loss: 0.5869
# Train Epoch 1 Progress: 81.07%	Loss: 0.3655
# Train Epoch 1 Progress: 82.13%	Loss: 0.2068
# Train Epoch 1 Progress: 83.2%	Loss: 0.2999
# Train Epoch 1 Progress: 84.27%	Loss: 0.1815
# Train Epoch 1 Progress: 85.33%	Loss: 0.3046
# Train Epoch 1 Progress: 86.4%	Loss: 0.2983
# Train Epoch 1 Progress: 87.47%	Loss: 0.3344
# Train Epoch 1 Progress: 88.53%	Loss: 0.212
# Train Epoch 1 Progress: 89.6%	Loss: 0.3954
# Train Epoch 1 Progress: 90.67%	Loss: 0.3628
# Train Epoch 1 Progress: 91.73%	Loss: 0.3912
# Train Epoch 1 Progress: 92.8%	Loss: 0.4112
# Train Epoch 1 Progress: 93.87%	Loss: 0.284
# Train Epoch 1 Progress: 94.93%	Loss: 0.2265
# Train Epoch 1 Progress: 96.0%	Loss: 0.3732
# Train Epoch 1 Progress: 97.07%	Loss: 0.148
# Train Epoch 1 Progress: 98.13%	Loss: 0.3275
# Train Epoch 1 Progress: 99.2%	Loss: 0.2679
#
# Test set: Avg loss 0.1054, Accuracy 96.61%
#
# Training with lr=0.01, momentum=0.5, batch_size=128
#
# Test set: Avg loss 2.313, Accuracy 10.02%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3227
# Train Epoch 0 Progress: 2.13%	Loss: 2.2808
# Train Epoch 0 Progress: 4.27%	Loss: 2.281
# Train Epoch 0 Progress: 6.4%	Loss: 2.2969
# Train Epoch 0 Progress: 8.53%	Loss: 2.2596
# Train Epoch 0 Progress: 10.67%	Loss: 2.2656
# Train Epoch 0 Progress: 12.8%	Loss: 2.2543
# Train Epoch 0 Progress: 14.93%	Loss: 2.214
# Train Epoch 0 Progress: 17.07%	Loss: 2.1247
# Train Epoch 0 Progress: 19.2%	Loss: 2.0852
# Train Epoch 0 Progress: 21.33%	Loss: 2.0168
# Train Epoch 0 Progress: 23.47%	Loss: 1.9897
# Train Epoch 0 Progress: 25.6%	Loss: 1.8203
# Train Epoch 0 Progress: 27.73%	Loss: 1.67
# Train Epoch 0 Progress: 29.87%	Loss: 1.6226
# Train Epoch 0 Progress: 32.0%	Loss: 1.5442
# Train Epoch 0 Progress: 34.13%	Loss: 1.3545
# Train Epoch 0 Progress: 36.27%	Loss: 1.3555
# Train Epoch 0 Progress: 38.4%	Loss: 1.3855
# Train Epoch 0 Progress: 40.53%	Loss: 1.2259
# Train Epoch 0 Progress: 42.67%	Loss: 1.2222
# Train Epoch 0 Progress: 44.8%	Loss: 1.0535
# Train Epoch 0 Progress: 46.93%	Loss: 0.9009
# Train Epoch 0 Progress: 49.07%	Loss: 1.0592
# Train Epoch 0 Progress: 51.2%	Loss: 0.9565
# Train Epoch 0 Progress: 53.33%	Loss: 0.9132
# Train Epoch 0 Progress: 55.47%	Loss: 1.0103
# Train Epoch 0 Progress: 57.6%	Loss: 0.8664
# Train Epoch 0 Progress: 59.73%	Loss: 0.9772
# Train Epoch 0 Progress: 61.87%	Loss: 0.8068
# Train Epoch 0 Progress: 64.0%	Loss: 0.8438
# Train Epoch 0 Progress: 66.13%	Loss: 0.9628
# Train Epoch 0 Progress: 68.27%	Loss: 0.7416
# Train Epoch 0 Progress: 70.4%	Loss: 0.839
# Train Epoch 0 Progress: 72.53%	Loss: 0.9247
# Train Epoch 0 Progress: 74.67%	Loss: 0.7927
# Train Epoch 0 Progress: 76.8%	Loss: 0.845
# Train Epoch 0 Progress: 78.93%	Loss: 0.6168
# Train Epoch 0 Progress: 81.07%	Loss: 0.6526
# Train Epoch 0 Progress: 83.2%	Loss: 0.5214
# Train Epoch 0 Progress: 85.33%	Loss: 0.5432
# Train Epoch 0 Progress: 87.47%	Loss: 0.5741
# Train Epoch 0 Progress: 89.6%	Loss: 0.905
# Train Epoch 0 Progress: 91.73%	Loss: 0.6482
# Train Epoch 0 Progress: 93.87%	Loss: 0.5442
# Train Epoch 0 Progress: 96.0%	Loss: 0.6757
# Train Epoch 0 Progress: 98.13%	Loss: 0.6903
#
# Test set: Avg loss 0.3263, Accuracy 91.43%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.605
# Train Epoch 1 Progress: 2.13%	Loss: 0.5563
# Train Epoch 1 Progress: 4.27%	Loss: 0.7453
# Train Epoch 1 Progress: 6.4%	Loss: 0.5323
# Train Epoch 1 Progress: 8.53%	Loss: 0.5481
# Train Epoch 1 Progress: 10.67%	Loss: 0.6191
# Train Epoch 1 Progress: 12.8%	Loss: 0.6304
# Train Epoch 1 Progress: 14.93%	Loss: 0.5513
# Train Epoch 1 Progress: 17.07%	Loss: 0.5679
# Train Epoch 1 Progress: 19.2%	Loss: 0.5206
# Train Epoch 1 Progress: 21.33%	Loss: 0.7828
# Train Epoch 1 Progress: 23.47%	Loss: 0.6234
# Train Epoch 1 Progress: 25.6%	Loss: 0.4404
# Train Epoch 1 Progress: 27.73%	Loss: 0.6806
# Train Epoch 1 Progress: 29.87%	Loss: 0.5149
# Train Epoch 1 Progress: 32.0%	Loss: 0.6043
# Train Epoch 1 Progress: 34.13%	Loss: 0.5933
# Train Epoch 1 Progress: 36.27%	Loss: 0.5857
# Train Epoch 1 Progress: 38.4%	Loss: 0.5345
# Train Epoch 1 Progress: 40.53%	Loss: 0.5117
# Train Epoch 1 Progress: 42.67%	Loss: 0.6202
# Train Epoch 1 Progress: 44.8%	Loss: 0.3942
# Train Epoch 1 Progress: 46.93%	Loss: 0.5373
# Train Epoch 1 Progress: 49.07%	Loss: 0.519
# Train Epoch 1 Progress: 51.2%	Loss: 0.6941
# Train Epoch 1 Progress: 53.33%	Loss: 0.5597
# Train Epoch 1 Progress: 55.47%	Loss: 0.5395
# Train Epoch 1 Progress: 57.6%	Loss: 0.5237
# Train Epoch 1 Progress: 59.73%	Loss: 0.3642
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1892829681.py in <cell line: 0>()
#      34     for epoch in range(n_epochs):
#      35         test_loss, test_accuracy = test(conv_network, flatten_data=False)
# ---> 36         train_loss_logs = train(conv_network, conv_optimizer, epoch, train_loader, flatten_data=False)
#      37         test_accuracies.append((epoch, test_accuracy))
#      38         test_losses.append((total_examples_seen, test_loss))
#
# /tmp/ipython-input-162600433.py in train(network, optimizer, epoch, trainloader, flatten_data)
#      27
#      28         # Backpropagation: Calculate the gradients of the loss with respect to the network's parameters
# ---> 29         loss.backward()
#      30
#      31         # Perform the optimization step: Update the network's parameters
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# Print the results sorted by accuracy
sorted_results = sorted(results, key=lambda x: x["test_accuracy"], reverse=True)
for result in sorted_results:
    print(result)

# %% [markdown]
# ## Insight into Saving Models
# A common way to save a model is to serialize the internal state dictionary (containing the model parameters).

# %%
torch.save(conv_network.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")

# %% [markdown]
# ## Insight into Loading Models
#
# The process for loading a model includes re-creating the model structure and loading
# the state dictionary into it.

# %%
# @title
model = ConvNet()
model.load_state_dict(torch.load("model.pth"))

# %% [markdown]
# This model can now be used to make predictions.

# %%
# @title
# Download test data from open datasets.
test_data = datasets.MNIST('sample_data/',
    train=False,
    download=True,
    transform=transforms.ToTensor(),
)

classes = [1, 2, 3, 4, 5, 6, 7, 8, 9]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
